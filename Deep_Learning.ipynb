# %%
import argparse
from datetime import datetime
from deepreg.train import train

name = "paired_mrus_brain"

log_root = f""
log_dir = "logs_train/" + datetime.now().strftime("%Y%m%d-%H%M%S")
config_path = [f"{name}.yaml"]

# %%
train(
    gpu="0", # gpu="0,1,2,3" for 4 GPUs
    config_path=config_path,
    gpu_allow_growth=False,
    ckpt_path="",
    log_dir=log_dir,
)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# moving_image (InputLayer)       [(8, 64, 64, 72)]    0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(8, 64, 64, 72, 1)] 0           moving_image[0][0]
# __________________________________________________________________________________________________
# fixed_image (InputLayer)        [(8, 64, 64, 72)]    0
# __________________________________________________________________________________________________
# resize3d (Resize3d)             (8, 64, 64, 72, 1)   0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_1 (Tenso [(8, 64, 64, 72, 1)] 0           fixed_image[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(8, 64, 64, 72, 2)] 0           resize3d[0][0]
#                                                                  tf_op_layer_ExpandDims_1[0][0]
# __________________________________________________________________________________________________
# Unet (UNet)                     (8, 64, 64, 72, 3)   9601139     tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# moving_label (InputLayer)       [(8, 64, 64, 72)]    0
# __________________________________________________________________________________________________
# fixed_label (InputLayer)        [(8, 64, 64, 72)]    0
# __________________________________________________________________________________________________
# indices (InputLayer)            [(8, 2)]             0
# __________________________________________________________________________________________________
# warping (Warping)               (8, 64, 64, 72)      0           Unet[0][0]
#                                                                  moving_image[0][0]
#                                                                  Unet[0][0]
#                                                                  moving_label[0][0]
# __________________________________________________________________________________________________
# BendingEnergy (BendingEnergy)   ()                   0           Unet[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [()]                 0           BendingEnergy[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# add_metric_1 (AddMetric)        ()                   0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_2 (Tenso [(8, 64, 64, 72, 1)] 0           fixed_image[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value/Minim [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_3 (Tenso [(8, 64, 64, 72, 1)] 0           warping[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value (Tens [(8, 64, 64, 72, 1)] 0           tf_op_layer_clip_by_value/Minimum
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value_1/Min [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(8, 294912, 1)]     0           tf_op_layer_clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value_1 (Te [(8, 64, 64, 72, 1)] 0           tf_op_layer_clip_by_value_1/Minim
# __________________________________________________________________________________________________
# tf_op_layer_sub_1 (TensorFlowOp [(8, 294912, 23)]    0           tf_op_layer_Reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1 (TensorFl [(8, 294912, 1)]     0           tf_op_layer_clip_by_value_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(8, 294912, 23)]    0           tf_op_layer_sub_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_2 (TensorFlowOp [(8, 294912, 23)]    0           tf_op_layer_Reshape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_3 (TensorFlowOp [(8, 294912, 23)]    0           tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_2 (TensorFlo [(8, 294912, 23)]    0           tf_op_layer_sub_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(8, 294912, 23)]    0           tf_op_layer_mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_4 (TensorFlowOp [(8, 294912, 23)]    0           tf_op_layer_Square_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(8, 294912, 1)]     0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(8, 294912, 23)]    0           tf_op_layer_mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_1 (TensorFl [(8, 294912, 23)]    0           tf_op_layer_Exp[0][0]
#                                                                  tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_1 (TensorFlowOp [(8, 294912, 1)]     0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose (TensorFl [(8, 23, 294912)]    0           tf_op_layer_truediv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_2 (TensorFl [(8, 294912, 23)]    0           tf_op_layer_Exp_1[0][0]
#                                                                  tf_op_layer_Sum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_1 (TensorFlo [(8, 23, 23)]        0           tf_op_layer_transpose[0][0]
#                                                                  tf_op_layer_truediv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [(8, 23, 1)]         0           tf_op_layer_transpose[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_2 (TensorFlowO [(8, 1, 23)]         0           tf_op_layer_truediv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_3 (TensorFl [(8, 23, 23)]        0           tf_op_layer_MatMul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul (TensorFlowO [(8, 23, 23)]        0           tf_op_layer_Mean_1[0][0]
#                                                                  tf_op_layer_Mean_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(8, 23, 23)]        0           tf_op_layer_truediv_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_1 (TensorFlowOp [(8, 23, 23)]        0           tf_op_layer_MatMul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_4 (TensorFl [(8, 23, 23)]        0           tf_op_layer_add[0][0]
#                                                                  tf_op_layer_add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_2 (TensorFlowOp [(8, 23, 23)]        0           tf_op_layer_truediv_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(8, 23, 23)]        0           tf_op_layer_add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_5 (TensorFlowOp [(8, 23, 23)]        0           tf_op_layer_truediv_3[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_2 (TensorFlowOp [(8,)]               0           tf_op_layer_mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg_2 (TensorFlowOp [(8,)]               0           tf_op_layer_Sum_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss/Mul ( [(8,)]               0           tf_op_layer_Neg_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss/Sum ( [()]                 0           tf_op_layer_weighted_loss/Mul[0][
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [()]                 0           tf_op_layer_weighted_loss/Sum[0][
# __________________________________________________________________________________________________
# tf_op_layer_Mul_6 (TensorFlowOp [()]                 0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# add_loss_1 (AddLoss)            ()                   0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# add_metric_2 (AddMetric)        ()                   0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# add_metric_3 (AddMetric)        ()                   0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_5 (Tenso [(8, 64, 64, 72, 1)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_7 (Tenso [(8, 64, 64, 72, 1)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_9 (Tenso [(8, 64, 64, 72, 1)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_11 (Tens [(8, 64, 64, 72, 1)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_13 (Tens [(8, 64, 64, 72, 1)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_4 (Tenso [(8, 64, 64, 72, 1)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_3 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_6 (Tenso [(8, 64, 64, 72, 1)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_9 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_8 (Tenso [(8, 64, 64, 72, 1)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_15 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_10 (Tens [(8, 64, 64, 72, 1)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_21 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_12 (Tens [(8, 64, 64, 72, 1)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_27 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D (TensorFlowO [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_4 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_6 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_10 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_12 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_16 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_18 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_22 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_24 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_ExpandDims_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_28 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_1 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_5 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_7 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_11 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_13 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_17 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_19 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_23 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_25 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_29 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_2 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_4 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_8 (TensorFlo [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_6 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_14 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_8 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_20 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_10 (T [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Conv3D_26 (TensorFl [(8, 64, 64, 72, 1)] 0           tf_op_layer_Conv3D_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_12 (T [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_29[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (8, 294912)          0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_3 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_5 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_8[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_7 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_14[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_9 (Te [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_20[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_10[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_11 (T [(8, 64, 64, 72)]    0           tf_op_layer_Conv3D_26[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (8, 294912)          0           tf_op_layer_strided_slice_12[0][0
# __________________________________________________________________________________________________
# flatten (Flatten)               (8, 294912)          0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_3 (TensorFlowOp [(8, 294912)]        0           flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_9 (TensorFlowOp [(8, 294912)]        0           flatten_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_15 (TensorFlowO [(8, 294912)]        0           flatten_5[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_21 (TensorFlowO [(8, 294912)]        0           flatten_7[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (8, 294912)          0           tf_op_layer_strided_slice_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_27 (TensorFlowO [(8, 294912)]        0           flatten_9[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (8, 294912)          0           tf_op_layer_strided_slice_11[0][0
# __________________________________________________________________________________________________
# tf_op_layer_add_33 (TensorFlowO [(8, 294912)]        0           flatten_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_5 (TensorFl [(8, 294912)]        0           flatten[0][0]
#                                                                  tf_op_layer_add_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_1 (TensorFl [(8, 294912)]        0           flatten[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_2 (TensorFl [(8, 294912)]        0           flatten_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_9 (TensorFl [(8, 294912)]        0           flatten_2[0][0]
#                                                                  tf_op_layer_add_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_4 (TensorFl [(8, 294912)]        0           flatten_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_5 (TensorFl [(8, 294912)]        0           flatten_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_13 (TensorF [(8, 294912)]        0           flatten_4[0][0]
#                                                                  tf_op_layer_add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_7 (TensorFl [(8, 294912)]        0           flatten_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_8 (TensorFl [(8, 294912)]        0           flatten_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_17 (TensorF [(8, 294912)]        0           flatten_6[0][0]
#                                                                  tf_op_layer_add_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_10 (TensorF [(8, 294912)]        0           flatten_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_11 (TensorF [(8, 294912)]        0           flatten_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_21 (TensorF [(8, 294912)]        0           flatten_8[0][0]
#                                                                  tf_op_layer_add_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_13 (TensorF [(8, 294912)]        0           flatten_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_14 (TensorF [(8, 294912)]        0           flatten_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_25 (TensorF [(8, 294912)]        0           flatten_10[0][0]
#                                                                  tf_op_layer_add_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_16 (TensorF [(8, 294912)]        0           flatten_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_17 (TensorF [(8, 294912)]        0           flatten_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater (TensorFlow [(8, 294912)]        0           tf_op_layer_truediv_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Less (TensorFlowOpL [(8, 294912)]        0           tf_op_layer_truediv_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_1 (TensorFlowO [(8, 294912)]        0           tf_op_layer_Greater_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_2 (TensorFlowO [(8, 294912)]        0           tf_op_layer_Greater_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_3 (TensorFl [(8, 294912)]        0           tf_op_layer_truediv_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Less_1 (TensorFlowO [(8, 294912)]        0           tf_op_layer_truediv_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_4 (TensorFlowO [(8, 294912)]        0           tf_op_layer_Greater_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_5 (TensorFlowO [(8, 294912)]        0           tf_op_layer_Greater_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_6 (TensorFl [(8, 294912)]        0           tf_op_layer_truediv_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Less_2 (TensorFlowO [(8, 294912)]        0           tf_op_layer_truediv_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_7 (TensorFlowO [(8, 294912)]        0           tf_op_layer_Greater_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_8 (TensorFlowO [(8, 294912)]        0           tf_op_layer_Greater_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_9 (TensorFl [(8, 294912)]        0           tf_op_layer_truediv_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Less_3 (TensorFlowO [(8, 294912)]        0           tf_op_layer_truediv_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_10 (TensorFlow [(8, 294912)]        0           tf_op_layer_Greater_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_11 (TensorFlow [(8, 294912)]        0           tf_op_layer_Greater_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_12 (TensorF [(8, 294912)]        0           tf_op_layer_truediv_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Less_4 (TensorFlowO [(8, 294912)]        0           tf_op_layer_truediv_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_13 (TensorFlow [(8, 294912)]        0           tf_op_layer_Greater_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_14 (TensorFlow [(8, 294912)]        0           tf_op_layer_Greater_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Greater_15 (TensorF [(8, 294912)]        0           tf_op_layer_truediv_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Less_5 (TensorFlowO [(8, 294912)]        0           tf_op_layer_truediv_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_16 (TensorFlow [(8, 294912)]        0           tf_op_layer_Greater_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_17 (TensorFlow [(8, 294912)]        0           tf_op_layer_Greater_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_and (TensorFlowOpLa [(8, 294912)]        0           tf_op_layer_Greater[0][0]
#                                                                  tf_op_layer_Less[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_4 (TensorFlowO [(8,)]               0           tf_op_layer_Cast_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_5 (TensorFlowO [(8,)]               0           tf_op_layer_Cast_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_and_1 (TensorFlowOp [(8, 294912)]        0           tf_op_layer_Greater_3[0][0]
#                                                                  tf_op_layer_Less_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_7 (TensorFlowO [(8,)]               0           tf_op_layer_Cast_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_8 (TensorFlowO [(8,)]               0           tf_op_layer_Cast_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_and_2 (TensorFlowOp [(8, 294912)]        0           tf_op_layer_Greater_6[0][0]
#                                                                  tf_op_layer_Less_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_10 (TensorFlow [(8,)]               0           tf_op_layer_Cast_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_11 (TensorFlow [(8,)]               0           tf_op_layer_Cast_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_and_3 (TensorFlowOp [(8, 294912)]        0           tf_op_layer_Greater_9[0][0]
#                                                                  tf_op_layer_Less_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_13 (TensorFlow [(8,)]               0           tf_op_layer_Cast_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_14 (TensorFlow [(8,)]               0           tf_op_layer_Cast_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_and_4 (TensorFlowOp [(8, 294912)]        0           tf_op_layer_Greater_12[0][0]
#                                                                  tf_op_layer_Less_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_16 (TensorFlow [(8,)]               0           tf_op_layer_Cast_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_17 (TensorFlow [(8,)]               0           tf_op_layer_Cast_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_and_5 (TensorFlowOp [(8, 294912)]        0           tf_op_layer_Greater_15[0][0]
#                                                                  tf_op_layer_Less_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_19 (TensorFlow [(8,)]               0           tf_op_layer_Cast_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_20 (TensorFlow [(8,)]               0           tf_op_layer_Cast_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast (TensorFlowOpL [(8, 294912)]        0           tf_op_layer_and[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_4 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_4[0][0]
#                                                                  tf_op_layer_Mean_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_3 (TensorFlowO [(8, 294912)]        0           tf_op_layer_and_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_10 (TensorFlowO [(8,)]               0           tf_op_layer_Mean_7[0][0]
#                                                                  tf_op_layer_Mean_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_6 (TensorFlowO [(8, 294912)]        0           tf_op_layer_and_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_16 (TensorFlowO [(8,)]               0           tf_op_layer_Mean_10[0][0]
#                                                                  tf_op_layer_Mean_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_9 (TensorFlowO [(8, 294912)]        0           tf_op_layer_and_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_22 (TensorFlowO [(8,)]               0           tf_op_layer_Mean_13[0][0]
#                                                                  tf_op_layer_Mean_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_12 (TensorFlow [(8, 294912)]        0           tf_op_layer_and_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_28 (TensorFlowO [(8,)]               0           tf_op_layer_Mean_16[0][0]
#                                                                  tf_op_layer_Mean_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_15 (TensorFlow [(8, 294912)]        0           tf_op_layer_and_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_34 (TensorFlowO [(8,)]               0           tf_op_layer_Mean_19[0][0]
#                                                                  tf_op_layer_Mean_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_3 (TensorFlowO [(8,)]               0           tf_op_layer_Cast[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_7 (TensorFlowOp [(8,)]               0           tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_6 (TensorFlowO [(8,)]               0           tf_op_layer_Cast_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_10 (TensorFlowO [(8,)]               0           tf_op_layer_add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_9 (TensorFlowO [(8,)]               0           tf_op_layer_Cast_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_13 (TensorFlowO [(8,)]               0           tf_op_layer_add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_12 (TensorFlow [(8,)]               0           tf_op_layer_Cast_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_16 (TensorFlowO [(8,)]               0           tf_op_layer_add_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_15 (TensorFlow [(8,)]               0           tf_op_layer_Cast_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_19 (TensorFlowO [(8,)]               0           tf_op_layer_add_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_18 (TensorFlow [(8,)]               0           tf_op_layer_Cast_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_22 (TensorFlowO [(8,)]               0           tf_op_layer_add_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_3 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_3[0][0]
#                                                                  tf_op_layer_mul_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_4 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_6[0][0]
#                                                                  tf_op_layer_mul_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_5 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_9[0][0]
#                                                                  tf_op_layer_mul_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_6 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_12[0][0]
#                                                                  tf_op_layer_mul_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_7 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_15[0][0]
#                                                                  tf_op_layer_mul_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_8 (TensorFlowOp [(8,)]               0           tf_op_layer_Mean_18[0][0]
#                                                                  tf_op_layer_mul_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_5 (TensorFlowOp [(8,)]               0           tf_op_layer_sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_9 (TensorFlowOp [(8,)]               0           tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_11 (TensorFlowO [(8,)]               0           tf_op_layer_sub_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_12 (TensorFlowO [(8,)]               0           tf_op_layer_add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_17 (TensorFlowO [(8,)]               0           tf_op_layer_sub_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_15 (TensorFlowO [(8,)]               0           tf_op_layer_add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_23 (TensorFlowO [(8,)]               0           tf_op_layer_sub_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_18 (TensorFlowO [(8,)]               0           tf_op_layer_add_22[0][0]
# ...
# Epoch 154/500
# 2/2 [==============================] - 58s 29s/step - loss: -0.2370 - loss/regularization_BendingEnergy: 0.0384 - loss/regularization_BendingEnergy_weighted: 0.0192 - loss/image_GlobalMutualInformationLoss: -0.5099 - loss/image_GlobalMutualInformationLoss_weighted: -0.2549 - loss/label_DiceScoreLoss: -0.0012 - loss/label_DiceScoreLoss_weighted: -0.0012 - val_loss: -0.0777 - val_loss/regularization_BendingEnergy: 0.0525 - val_loss/regularization_BendingEnergy_weighted: 0.0262 - val_loss/image_GlobalMutualInformationLoss: -0.2057 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1029 - val_loss/label_DiceScoreLoss: -0.0011 - val_loss/label_DiceScoreLoss_weighted: -0.0011
# Epoch 155/500
# 2/2 [==============================] - 56s 28s/step - loss: -0.2194 - loss/regularization_BendingEnergy: 0.0373 - loss/regularization_BendingEnergy_weighted: 0.0187 - loss/image_GlobalMutualInformationLoss: -0.4733 - loss/image_GlobalMutualInformationLoss_weighted: -0.2367 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014 - val_loss: -0.0540 - val_loss/regularization_BendingEnergy: 0.0594 - val_loss/regularization_BendingEnergy_weighted: 0.0297 - val_loss/image_GlobalMutualInformationLoss: -0.1653 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0827 - val_loss/label_DiceScoreLoss: -0.0011 - val_loss/label_DiceScoreLoss_weighted: -0.0011
# Epoch 156/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2258 - loss/regularization_BendingEnergy: 0.0396 - loss/regularization_BendingEnergy_weighted: 0.0198 - loss/image_GlobalMutualInformationLoss: -0.4882 - loss/image_GlobalMutualInformationLoss_weighted: -0.2441 - loss/label_DiceScoreLoss: -0.0015 - loss/label_DiceScoreLoss_weighted: -0.0015 - val_loss: -0.1016 - val_loss/regularization_BendingEnergy: 0.0523 - val_loss/regularization_BendingEnergy_weighted: 0.0262 - val_loss/image_GlobalMutualInformationLoss: -0.2530 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1265 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 157/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2264 - loss/regularization_BendingEnergy: 0.0393 - loss/regularization_BendingEnergy_weighted: 0.0197 - loss/image_GlobalMutualInformationLoss: -0.4892 - loss/image_GlobalMutualInformationLoss_weighted: -0.2446 - loss/label_DiceScoreLoss: -0.0015 - loss/label_DiceScoreLoss_weighted: -0.0015 - val_loss: -0.1087 - val_loss/regularization_BendingEnergy: 0.0527 - val_loss/regularization_BendingEnergy_weighted: 0.0264 - val_loss/image_GlobalMutualInformationLoss: -0.2675 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1338 - val_loss/label_DiceScoreLoss: -0.0013 - val_loss/label_DiceScoreLoss_weighted: -0.0013
# Epoch 158/500
# 2/2 [==============================] - 58s 29s/step - loss: -0.2257 - loss/regularization_BendingEnergy: 0.0394 - loss/regularization_BendingEnergy_weighted: 0.0197 - loss/image_GlobalMutualInformationLoss: -0.4884 - loss/image_GlobalMutualInformationLoss_weighted: -0.2442 - loss/label_DiceScoreLoss: -0.0013 - loss/label_DiceScoreLoss_weighted: -0.0013 - val_loss: -0.1229 - val_loss/regularization_BendingEnergy: 0.0497 - val_loss/regularization_BendingEnergy_weighted: 0.0249 - val_loss/image_GlobalMutualInformationLoss: -0.2932 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1466 - val_loss/label_DiceScoreLoss: -0.0011 - val_loss/label_DiceScoreLoss_weighted: -0.0011
# Epoch 159/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2265 - loss/regularization_BendingEnergy: 0.0397 - loss/regularization_BendingEnergy_weighted: 0.0198 - loss/image_GlobalMutualInformationLoss: -0.4906 - loss/image_GlobalMutualInformationLoss_weighted: -0.2453 - loss/label_DiceScoreLoss: -0.0010 - loss/label_DiceScoreLoss_weighted: -0.0010 - val_loss: -0.1291 - val_loss/regularization_BendingEnergy: 0.0469 - val_loss/regularization_BendingEnergy_weighted: 0.0234 - val_loss/image_GlobalMutualInformationLoss: -0.3023 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1512 - val_loss/label_DiceScoreLoss: -0.0013 - val_loss/label_DiceScoreLoss_weighted: -0.0013
# Epoch 160/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2236 - loss/regularization_BendingEnergy: 0.0367 - loss/regularization_BendingEnergy_weighted: 0.0184 - loss/image_GlobalMutualInformationLoss: -0.4808 - loss/image_GlobalMutualInformationLoss_weighted: -0.2404 - loss/label_DiceScoreLoss: -0.0015 - loss/label_DiceScoreLoss_weighted: -0.0015 - val_loss: -0.1229 - val_loss/regularization_BendingEnergy: 0.0439 - val_loss/regularization_BendingEnergy_weighted: 0.0219 - val_loss/image_GlobalMutualInformationLoss: -0.2870 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1435 - val_loss/label_DiceScoreLoss: -0.0014 - val_loss/label_DiceScoreLoss_weighted: -0.0014
# Epoch 161/500
# 2/2 [==============================] - 58s 29s/step - loss: -0.2208 - loss/regularization_BendingEnergy: 0.0370 - loss/regularization_BendingEnergy_weighted: 0.0185 - loss/image_GlobalMutualInformationLoss: -0.4761 - loss/image_GlobalMutualInformationLoss_weighted: -0.2381 - loss/label_DiceScoreLoss: -0.0013 - loss/label_DiceScoreLoss_weighted: -0.0013 - val_loss: -0.1568 - val_loss/regularization_BendingEnergy: 0.0394 - val_loss/regularization_BendingEnergy_weighted: 0.0197 - val_loss/image_GlobalMutualInformationLoss: -0.3500 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1750 - val_loss/label_DiceScoreLoss: -0.0015 - val_loss/label_DiceScoreLoss_weighted: -0.0015
# Epoch 162/500
# 2/2 [==============================] - 58s 29s/step - loss: -0.2234 - loss/regularization_BendingEnergy: 0.0366 - loss/regularization_BendingEnergy_weighted: 0.0183 - loss/image_GlobalMutualInformationLoss: -0.4805 - loss/image_GlobalMutualInformationLoss_weighted: -0.2403 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014 - val_loss: -0.1716 - val_loss/regularization_BendingEnergy: 0.0396 - val_loss/regularization_BendingEnergy_weighted: 0.0198 - val_loss/image_GlobalMutualInformationLoss: -0.3797 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1899 - val_loss/label_DiceScoreLoss: -0.0015 - val_loss/label_DiceScoreLoss_weighted: -0.0015
# Epoch 163/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2269 - loss/regularization_BendingEnergy: 0.0390 - loss/regularization_BendingEnergy_weighted: 0.0195 - loss/image_GlobalMutualInformationLoss: -0.4896 - loss/image_GlobalMutualInformationLoss_weighted: -0.2448 - loss/label_DiceScoreLoss: -0.0016 - loss/label_DiceScoreLoss_weighted: -0.0016 - val_loss: -0.1409 - val_loss/regularization_BendingEnergy: 0.0448 - val_loss/regularization_BendingEnergy_weighted: 0.0224 - val_loss/image_GlobalMutualInformationLoss: -0.3242 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1621 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 164/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2283 - loss/regularization_BendingEnergy: 0.0383 - loss/regularization_BendingEnergy_weighted: 0.0191 - loss/image_GlobalMutualInformationLoss: -0.4927 - loss/image_GlobalMutualInformationLoss_weighted: -0.2463 - loss/label_DiceScoreLoss: -0.0011 - loss/label_DiceScoreLoss_weighted: -0.0011 - val_loss: -0.1489 - val_loss/regularization_BendingEnergy: 0.0436 - val_loss/regularization_BendingEnergy_weighted: 0.0218 - val_loss/image_GlobalMutualInformationLoss: -0.3391 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1695 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 165/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2348 - loss/regularization_BendingEnergy: 0.0369 - loss/regularization_BendingEnergy_weighted: 0.0184 - loss/image_GlobalMutualInformationLoss: -0.5036 - loss/image_GlobalMutualInformationLoss_weighted: -0.2518 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014 - val_loss: -0.1644 - val_loss/regularization_BendingEnergy: 0.0408 - val_loss/regularization_BendingEnergy_weighted: 0.0204 - val_loss/image_GlobalMutualInformationLoss: -0.3664 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1832 - val_loss/label_DiceScoreLoss: -0.0016 - val_loss/label_DiceScoreLoss_weighted: -0.0016
# Epoch 166/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2423 - loss/regularization_BendingEnergy: 0.0385 - loss/regularization_BendingEnergy_weighted: 0.0192 - loss/image_GlobalMutualInformationLoss: -0.5204 - loss/image_GlobalMutualInformationLoss_weighted: -0.2602 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014 - val_loss: -0.1579 - val_loss/regularization_BendingEnergy: 0.0386 - val_loss/regularization_BendingEnergy_weighted: 0.0193 - val_loss/image_GlobalMutualInformationLoss: -0.3511 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1755 - val_loss/label_DiceScoreLoss: -0.0016 - val_loss/label_DiceScoreLoss_weighted: -0.0016
# Epoch 167/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2234 - loss/regularization_BendingEnergy: 0.0391 - loss/regularization_BendingEnergy_weighted: 0.0196 - loss/image_GlobalMutualInformationLoss: -0.4837 - loss/image_GlobalMutualInformationLoss_weighted: -0.2418 - loss/label_DiceScoreLoss: -0.0012 - loss/label_DiceScoreLoss_weighted: -0.0012 - val_loss: -0.1409 - val_loss/regularization_BendingEnergy: 0.0409 - val_loss/regularization_BendingEnergy_weighted: 0.0204 - val_loss/image_GlobalMutualInformationLoss: -0.3197 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1599 - val_loss/label_DiceScoreLoss: -0.0015 - val_loss/label_DiceScoreLoss_weighted: -0.0015
# Epoch 168/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2288 - loss/regularization_BendingEnergy: 0.0388 - loss/regularization_BendingEnergy_weighted: 0.0194 - loss/image_GlobalMutualInformationLoss: -0.4937 - loss/image_GlobalMutualInformationLoss_weighted: -0.2469 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014 - val_loss: -0.1591 - val_loss/regularization_BendingEnergy: 0.0399 - val_loss/regularization_BendingEnergy_weighted: 0.0200 - val_loss/image_GlobalMutualInformationLoss: -0.3550 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1775 - val_loss/label_DiceScoreLoss: -0.0015 - val_loss/label_DiceScoreLoss_weighted: -0.0015
# Epoch 169/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2342 - loss/regularization_BendingEnergy: 0.0369 - loss/regularization_BendingEnergy_weighted: 0.0185 - loss/image_GlobalMutualInformationLoss: -0.5025 - loss/image_GlobalMutualInformationLoss_weighted: -0.2512 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014 - val_loss: -0.1641 - val_loss/regularization_BendingEnergy: 0.0406 - val_loss/regularization_BendingEnergy_weighted: 0.0203 - val_loss/image_GlobalMutualInformationLoss: -0.3658 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1829 - val_loss/label_DiceScoreLoss: -0.0015 - val_loss/label_DiceScoreLoss_weighted: -0.0015
# Epoch 170/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2224 - loss/regularization_BendingEnergy: 0.0400 - loss/regularization_BendingEnergy_weighted: 0.0200 - loss/image_GlobalMutualInformationLoss: -0.4824 - loss/image_GlobalMutualInformationLoss_weighted: -0.2412 - loss/label_DiceScoreLoss: -0.0012 - loss/label_DiceScoreLoss_weighted: -0.0012 - val_loss: -0.1601 - val_loss/regularization_BendingEnergy: 0.0416 - val_loss/regularization_BendingEnergy_weighted: 0.0208 - val_loss/image_GlobalMutualInformationLoss: -0.3593 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1796 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 171/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2349 - loss/regularization_BendingEnergy: 0.0391 - loss/regularization_BendingEnergy_weighted: 0.0196 - loss/image_GlobalMutualInformationLoss: -0.5064 - loss/image_GlobalMutualInformationLoss_weighted: -0.2532 - loss/label_DiceScoreLoss: -0.0013 - loss/label_DiceScoreLoss_weighted: -0.0013 - val_loss: -0.1631 - val_loss/regularization_BendingEnergy: 0.0405 - val_loss/regularization_BendingEnergy_weighted: 0.0202 - val_loss/image_GlobalMutualInformationLoss: -0.3643 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1822 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 172/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2396 - loss/regularization_BendingEnergy: 0.0375 - loss/regularization_BendingEnergy_weighted: 0.0188 - loss/image_GlobalMutualInformationLoss: -0.5143 - loss/image_GlobalMutualInformationLoss_weighted: -0.2571 - loss/label_DiceScoreLoss: -0.0012 - loss/label_DiceScoreLoss_weighted: -0.0012 - val_loss: -0.1799 - val_loss/regularization_BendingEnergy: 0.0378 - val_loss/regularization_BendingEnergy_weighted: 0.0189 - val_loss/image_GlobalMutualInformationLoss: -0.3951 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1976 - val_loss/label_DiceScoreLoss: -0.0013 - val_loss/label_DiceScoreLoss_weighted: -0.0013
# Epoch 173/500
# 2/2 [==============================] - 57s 29s/step - loss: -0.2392 - loss/regularization_BendingEnergy: 0.0360 - loss/regularization_BendingEnergy_weighted: 0.0180 - loss/image_GlobalMutualInformationLoss: -0.5119 - loss/image_GlobalMutualInformationLoss_weighted: -0.2559 - loss/label_DiceScoreLoss: -0.0013 - loss/label_DiceScoreLoss_weighted: -0.0013 - val_loss: -0.1772 - val_loss/regularization_BendingEnergy: 0.0373 - val_loss/regularization_BendingEnergy_weighted: 0.0187 - val_loss/image_GlobalMutualInformationLoss: -0.3893 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1947 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 174/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2297 - loss/regularization_BendingEnergy: 0.0366 - loss/regularization_BendingEnergy_weighted: 0.0183 - loss/image_GlobalMutualInformationLoss: -0.4936 - loss/image_GlobalMutualInformationLoss_weighted: -0.2468 - loss/label_DiceScoreLoss: -0.0012 - loss/label_DiceScoreLoss_weighted: -0.0012 - val_loss: -0.1696 - val_loss/regularization_BendingEnergy: 0.0389 - val_loss/regularization_BendingEnergy_weighted: 0.0195 - val_loss/image_GlobalMutualInformationLoss: -0.3758 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1879 - val_loss/label_DiceScoreLoss: -0.0012 - val_loss/label_DiceScoreLoss_weighted: -0.0012
# Epoch 175/500
# 2/2 [==============================] - 57s 28s/step - loss: -0.2436 - loss/regularization_BendingEnergy: 0.0350 - loss/regularization_BendingEnergy_weighted: 0.0175 - loss/image_GlobalMutualInformationLoss: -0.5191 - loss/image_GlobalMutualInformationLoss_weighted: -0.2596 - loss/label_DiceScoreLoss: -0.0015 - loss/label_DiceScoreLoss_weighted: -0.0015 - val_loss: -0.1604 - val_loss/regularization_BendingEnergy: 0.0391 - val_loss/regularization_BendingEnergy_weighted: 0.0196 - val_loss/image_GlobalMutualInformationLoss: -0.3573 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.1786 - val_loss/label_DiceScoreLoss: -0.0013 - val_loss/label_DiceScoreLoss_weighted: -0.0013
# Epoch 176/500
# 2/2 [==============================] - ETA: 0s - loss: -0.2332 - loss/regularization_BendingEnergy: 0.0356 - loss/regularization_BendingEnergy_weighted: 0.0178 - loss/image_GlobalMutualInformationLoss: -0.4993 - loss/image_GlobalMutualInformationLoss_weighted: -0.2497 - loss/label_DiceScoreLoss: -0.0014 - loss/label_DiceScoreLoss_weighted: -0.0014
