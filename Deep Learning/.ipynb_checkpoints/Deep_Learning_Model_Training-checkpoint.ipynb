# %%
import argparse
from datetime import datetime

from deepreg.train import train

name = "paired_mrus_brain"

log_root = f""
log_dir = "logs_train/" + datetime.now().strftime("%Y%m%d-%H%M%S")
config_path = [f"{name}.yaml"]

# %%
history = train(
    gpu="0", 
    config_path=config_path,
    gpu_allow_growth=False,
    ckpt_path="",
    log_dir=log_dir,
)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# moving_image (InputLayer)       [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(2, 151, 136, 119,  0           moving_image[0][0]
# __________________________________________________________________________________________________
# fixed_image (InputLayer)        [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# resize3d (Resize3d)             (2, 151, 136, 119, 1 0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_1 (Tenso [(2, 151, 136, 119,  0           fixed_image[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(2, 151, 136, 119,  0           resize3d[0][0]
#                                                                  tf_op_layer_ExpandDims_1[0][0]
# __________________________________________________________________________________________________
# LocalNet (LocalNet)             (2, 151, 136, 119, 3 1502236     tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# moving_label (InputLayer)       [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# fixed_label (InputLayer)        [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# indices (InputLayer)            [(2, 2)]             0
# __________________________________________________________________________________________________
# warping (Warping)               (2, 151, 136, 119)   0           LocalNet[0][0]
#                                                                  moving_image[0][0]
#                                                                  LocalNet[0][0]
#                                                                  moving_label[0][0]
# __________________________________________________________________________________________________
# BendingEnergy (BendingEnergy)   ()                   0           LocalNet[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [()]                 0           BendingEnergy[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# add_metric_1 (AddMetric)        ()                   0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_2 (Tenso [(2, 151, 136, 119,  0           fixed_image[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value/Minim [(2, 151, 136, 119,  0           tf_op_layer_ExpandDims_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_3 (Tenso [(2, 151, 136, 119,  0           warping[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value (Tens [(2, 151, 136, 119,  0           tf_op_layer_clip_by_value/Minimum
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value_1/Min [(2, 151, 136, 119,  0           tf_op_layer_ExpandDims_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(2, 2443784, 1)]    0           tf_op_layer_clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value_1 (Te [(2, 151, 136, 119,  0           tf_op_layer_clip_by_value_1/Minim
# __________________________________________________________________________________________________
# tf_op_layer_sub_1 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1 (TensorFl [(2, 2443784, 1)]    0           tf_op_layer_clip_by_value_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(2, 2443784, 23)]   0           tf_op_layer_sub_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_2 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Reshape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_3 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_2 (TensorFlo [(2, 2443784, 23)]   0           tf_op_layer_sub_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(2, 2443784, 23)]   0           tf_op_layer_mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_4 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Square_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(2, 2443784, 1)]    0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_1 (TensorFl [(2, 2443784, 23)]   0           tf_op_layer_Exp[0][0]
#                                                                  tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_1 (TensorFlowOp [(2, 2443784, 1)]    0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose (TensorFl [(2, 23, 2443784)]   0           tf_op_layer_truediv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_2 (TensorFl [(2, 2443784, 23)]   0           tf_op_layer_Exp_1[0][0]
#                                                                  tf_op_layer_Sum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_1 (TensorFlo [(2, 23, 23)]        0           tf_op_layer_transpose[0][0]
#                                                                  tf_op_layer_truediv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [(2, 23, 1)]         0           tf_op_layer_transpose[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_2 (TensorFlowO [(2, 1, 23)]         0           tf_op_layer_truediv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_3 (TensorFl [(2, 23, 23)]        0           tf_op_layer_MatMul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul (TensorFlowO [(2, 23, 23)]        0           tf_op_layer_Mean_1[0][0]
#                                                                  tf_op_layer_Mean_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(2, 23, 23)]        0           tf_op_layer_truediv_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_1 (TensorFlowOp [(2, 23, 23)]        0           tf_op_layer_MatMul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_4 (TensorFl [(2, 23, 23)]        0           tf_op_layer_add[0][0]
#                                                                  tf_op_layer_add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_2 (TensorFlowOp [(2, 23, 23)]        0           tf_op_layer_truediv_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(2, 23, 23)]        0           tf_op_layer_add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_5 (TensorFlowOp [(2, 23, 23)]        0           tf_op_layer_truediv_3[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_2 (TensorFlowOp [(2,)]               0           tf_op_layer_mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg_2 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss/Mul ( [(2,)]               0           tf_op_layer_Neg_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss/Sum ( [()]                 0           tf_op_layer_weighted_loss/Mul[0][
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [()]                 0           tf_op_layer_weighted_loss/Sum[0][
# __________________________________________________________________________________________________
# tf_op_layer_Mul_6 (TensorFlowOp [()]                 0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# add_loss_1 (AddLoss)            ()                   0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# add_metric_2 (AddMetric)        ()                   0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# add_metric_3 (AddMetric)        ()                   0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_5 (Tensor [(2, 119, 136, 151)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_6 (Tensor [(2, 119, 136, 151)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_1 (Tensor [(2, 119, 136, 151)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_2 (Tensor [(2, 119, 136, 151)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_7 (Tensor [(2, 151, 119, 136)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_8 (Tensor [(2, 151, 119, 136)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_3 (Tensor [(2, 151, 119, 136)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_4 (Tensor [(2, 151, 119, 136)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_8 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_9 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_2 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_3 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_10 (TensorFl [(2, 151, 119, 1)]   0           tf_op_layer_transpose_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_11 (TensorFl [(2, 151, 119, 1)]   0           tf_op_layer_transpose_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_4 (TensorFlo [(2, 151, 119, 1)]   0           tf_op_layer_transpose_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_5 (TensorFlo [(2, 151, 119, 1)]   0           tf_op_layer_transpose_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_9 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_10 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_3 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_4 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_11 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_12 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_5 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_6 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_12 (TensorFl [(2, 151, 136, 1)]   0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_13 (TensorFl [(2, 151, 136, 1)]   0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_6 (TensorFlo [(2, 151, 136, 1)]   0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_7 (TensorFlo [(2, 151, 136, 1)]   0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_9 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_10 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_3 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_4 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_11 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_12 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_5 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_6 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_13 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_14 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_7 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_8 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_8 (TensorFl [(2,)]               0           tf_op_layer_add_9[0][0]
#                                                                  tf_op_layer_add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_5 (TensorFl [(2,)]               0           tf_op_layer_add_3[0][0]
#                                                                  tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_9 (TensorFl [(2,)]               0           tf_op_layer_add_11[0][0]
#                                                                  tf_op_layer_add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_6 (TensorFl [(2,)]               0           tf_op_layer_add_5[0][0]
#                                                                  tf_op_layer_add_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_13 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_14 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_7 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_8 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_3 (TensorFlowOp [(2,)]               0           tf_op_layer_truediv_8[0][0]
#                                                                  tf_op_layer_truediv_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_4 (TensorFlowOp [(2,)]               0           tf_op_layer_truediv_9[0][0]
#                                                                  tf_op_layer_truediv_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_10 (TensorF [(2,)]               0           tf_op_layer_add_13[0][0]
#                                                                  tf_op_layer_add_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_7 (TensorFl [(2,)]               0           tf_op_layer_add_7[0][0]
#                                                                  tf_op_layer_add_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow (TensorFlowOpLa [(2,)]               0           tf_op_layer_sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow_1 (TensorFlowOp [(2,)]               0           tf_op_layer_sub_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_5 (TensorFlowOp [(2,)]               0           tf_op_layer_truediv_10[0][0]
#                                                                  tf_op_layer_truediv_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_15 (TensorFlowO [(2,)]               0           tf_op_layer_pow[0][0]
#                                                                  tf_op_layer_pow_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow_2 (TensorFlowOp [(2,)]               0           tf_op_layer_sub_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_16 (TensorFlowO [(2,)]               0           tf_op_layer_add_15[0][0]
#                                                                  tf_op_layer_pow_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(2,)]               0           tf_op_layer_add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss_1/Mul [(2,)]               0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss_1/Sum [()]                 0           tf_op_layer_weighted_loss_1/Mul[0
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_2 (TensorFl [()]                 0           tf_op_layer_weighted_loss_1/Sum[0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_7 (TensorFlowOp [()]                 0           tf_op_layer_RealDiv_2[0][0]
# __________________________________________________________________________________________________
# add_loss_2 (AddLoss)            ()                   0           tf_op_layer_Mul_7[0][0]
# __________________________________________________________________________________________________
# add_metric_4 (AddMetric)        ()                   0           tf_op_layer_RealDiv_2[0][0]
# __________________________________________________________________________________________________
# add_metric_5 (AddMetric)        ()                   0           tf_op_layer_Mul_7[0][0]
# ==================================================================================================
# Total params: 1,502,236
# Trainable params: 1,500,412
# Non-trainable params: 1,824
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# 1/1 [==============================] - 0s 165ms/step - loss: 0.1522 - loss/regularization_BendingEnergy: 0.0000e+00 - loss/regularization_BendingEnergy_weighted: 0.0000e+00 - loss/image_GlobalMutualInformationLoss: -0.0523 - loss/image_GlobalMutualInformationLoss_weighted: -0.0262 - loss/label_L2_Distance: 17.8390 - loss/label_L2_Distance_weighted: 0.1784
# Epoch 1/4000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0850 - loss/regularization_BendingEnergy: 4.4710e-09 - loss/regularization_BendingEnergy_weighted: 2.2355e-09 - loss/image_GlobalMutualInformationLoss: -0.1077 - loss/image_GlobalMutualInformationLoss_weighted: -0.0539 - loss/label_L2_Distance: 13.8842 - loss/label_L2_Distance_weighted: 0.1388WARNING:tensorflow:From /home/dmanwill/anaconda3/envs/MMIR/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:From /home/dmanwill/anaconda3/envs/MMIR/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 2/8 [======>.......................] - ETA: 33s - loss: 0.0808 - loss/regularization_BendingEnergy: 8.6613e-09 - loss/regularization_BendingEnergy_weighted: 4.3307e-09 - loss/image_GlobalMutualInformationLoss: -0.1077 - loss/image_GlobalMutualInformationLoss_weighted: -0.0539 - loss/label_L2_Distance: 13.4708 - loss/label_L2_Distance_weighted: 0.1347WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 4.2183s vs `on_train_batch_end` time: 7.0077s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 4.2183s vs `on_train_batch_end` time: 7.0077s). Check your callbacks.
# 8/8 [==============================] - 59s 7s/step - loss: 0.0791 - loss/regularization_BendingEnergy: 6.2447e-08 - loss/regularization_BendingEnergy_weighted: 3.1223e-08 - loss/image_GlobalMutualInformationLoss: -0.1027 - loss/image_GlobalMutualInformationLoss_weighted: -0.0514 - loss/label_L2_Distance: 13.0437 - loss/label_L2_Distance_weighted: 0.1304 - val_loss: -0.0046 - val_loss/regularization_BendingEnergy: 2.0063e-10 - val_loss/regularization_BendingEnergy_weighted: 1.0032e-10 - val_loss/image_GlobalMutualInformationLoss: -0.0579 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4353 - val_loss/label_L2_Distance_weighted: 0.0244
# Epoch 2/4000
# 8/8 [==============================] - 36s 4s/step - loss: 0.1825 - loss/regularization_BendingEnergy: 2.2608e-07 - loss/regularization_BendingEnergy_weighted: 1.1304e-07 - loss/image_GlobalMutualInformationLoss: -0.0309 - loss/image_GlobalMutualInformationLoss_weighted: -0.0154 - loss/label_L2_Distance: 19.7976 - loss/label_L2_Distance_weighted: 0.1980 - val_loss: -0.0046 - val_loss/regularization_BendingEnergy: 1.3755e-09 - val_loss/regularization_BendingEnergy_weighted: 6.8777e-10 - val_loss/image_GlobalMutualInformationLoss: -0.0579 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4328 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 3/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0808 - loss/regularization_BendingEnergy: 5.2068e-07 - loss/regularization_BendingEnergy_weighted: 2.6034e-07 - loss/image_GlobalMutualInformationLoss: -0.0381 - loss/image_GlobalMutualInformationLoss_weighted: -0.0190 - loss/label_L2_Distance: 9.9850 - loss/label_L2_Distance_weighted: 0.0998 - val_loss: -0.0047 - val_loss/regularization_BendingEnergy: 5.1414e-09 - val_loss/regularization_BendingEnergy_weighted: 2.5707e-09 - val_loss/image_GlobalMutualInformationLoss: -0.0579 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4291 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 4/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0912 - loss/regularization_BendingEnergy: 1.1222e-06 - loss/regularization_BendingEnergy_weighted: 5.6111e-07 - loss/image_GlobalMutualInformationLoss: -0.0365 - loss/image_GlobalMutualInformationLoss_weighted: -0.0182 - loss/label_L2_Distance: 10.9454 - loss/label_L2_Distance_weighted: 0.1095 - val_loss: -0.0047 - val_loss/regularization_BendingEnergy: 1.2420e-08 - val_loss/regularization_BendingEnergy_weighted: 6.2098e-09 - val_loss/image_GlobalMutualInformationLoss: -0.0580 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4255 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 5/4000
# 8/8 [==============================] - 36s 4s/step - loss: 0.1132 - loss/regularization_BendingEnergy: 2.3225e-06 - loss/regularization_BendingEnergy_weighted: 1.1613e-06 - loss/image_GlobalMutualInformationLoss: -0.0376 - loss/image_GlobalMutualInformationLoss_weighted: -0.0188 - loss/label_L2_Distance: 13.1990 - loss/label_L2_Distance_weighted: 0.1320 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 2.4914e-08 - val_loss/regularization_BendingEnergy_weighted: 1.2457e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0580 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4218 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 6/4000
# 8/8 [==============================] - 36s 4s/step - loss: 0.0959 - loss/regularization_BendingEnergy: 4.4637e-06 - loss/regularization_BendingEnergy_weighted: 2.2318e-06 - loss/image_GlobalMutualInformationLoss: -0.0349 - loss/image_GlobalMutualInformationLoss_weighted: -0.0174 - loss/label_L2_Distance: 11.3308 - loss/label_L2_Distance_weighted: 0.1133 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 4.4214e-08 - val_loss/regularization_BendingEnergy_weighted: 2.2107e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0580 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4191 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 7/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.0856 - loss/regularization_BendingEnergy: 6.8128e-06 - loss/regularization_BendingEnergy_weighted: 3.4064e-06 - loss/image_GlobalMutualInformationLoss: -0.0409 - loss/image_GlobalMutualInformationLoss_weighted: -0.0204 - loss/label_L2_Distance: 10.6051 - loss/label_L2_Distance_weighted: 0.1061 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 6.9493e-08 - val_loss/regularization_BendingEnergy_weighted: 3.4747e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4155 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 8/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0927 - loss/regularization_BendingEnergy: 9.2952e-06 - loss/regularization_BendingEnergy_weighted: 4.6476e-06 - loss/image_GlobalMutualInformationLoss: -0.0363 - loss/image_GlobalMutualInformationLoss_weighted: -0.0182 - loss/label_L2_Distance: 11.0861 - loss/label_L2_Distance_weighted: 0.1109 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 9.5018e-08 - val_loss/regularization_BendingEnergy_weighted: 4.7509e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4138 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 9/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0878 - loss/regularization_BendingEnergy: 1.2240e-05 - loss/regularization_BendingEnergy_weighted: 6.1199e-06 - loss/image_GlobalMutualInformationLoss: -0.0378 - loss/image_GlobalMutualInformationLoss_weighted: -0.0189 - loss/label_L2_Distance: 10.6688 - loss/label_L2_Distance_weighted: 0.1067 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.2262e-07 - val_loss/regularization_BendingEnergy_weighted: 6.1308e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4147 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 10/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1536 - loss/regularization_BendingEnergy: 1.8036e-05 - loss/regularization_BendingEnergy_weighted: 9.0180e-06 - loss/image_GlobalMutualInformationLoss: -0.0438 - loss/image_GlobalMutualInformationLoss_weighted: -0.0219 - loss/label_L2_Distance: 17.5444 - loss/label_L2_Distance_weighted: 0.1754 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.5652e-07 - val_loss/regularization_BendingEnergy_weighted: 7.8258e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4138 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 11/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1392 - loss/regularization_BendingEnergy: 2.3938e-05 - loss/regularization_BendingEnergy_weighted: 1.1969e-05 - loss/image_GlobalMutualInformationLoss: -0.0523 - loss/image_GlobalMutualInformationLoss_weighted: -0.0262 - loss/label_L2_Distance: 16.5384 - loss/label_L2_Distance_weighted: 0.1654 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 1.7812e-07 - val_loss/regularization_BendingEnergy_weighted: 8.9062e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4110 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 12/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1263 - loss/regularization_BendingEnergy: 2.5042e-05 - loss/regularization_BendingEnergy_weighted: 1.2521e-05 - loss/image_GlobalMutualInformationLoss: -0.0595 - loss/image_GlobalMutualInformationLoss_weighted: -0.0298 - loss/label_L2_Distance: 15.6090 - loss/label_L2_Distance_weighted: 0.1561 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 1.9933e-07 - val_loss/regularization_BendingEnergy_weighted: 9.9666e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4086 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 13/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0998 - loss/regularization_BendingEnergy: 3.1433e-05 - loss/regularization_BendingEnergy_weighted: 1.5716e-05 - loss/image_GlobalMutualInformationLoss: -0.0707 - loss/image_GlobalMutualInformationLoss_weighted: -0.0353 - loss/label_L2_Distance: 13.5075 - loss/label_L2_Distance_weighted: 0.1351 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 2.1459e-07 - val_loss/regularization_BendingEnergy_weighted: 1.0729e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4065 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 14/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.0927 - loss/regularization_BendingEnergy: 3.7321e-05 - loss/regularization_BendingEnergy_weighted: 1.8660e-05 - loss/image_GlobalMutualInformationLoss: -0.0638 - loss/image_GlobalMutualInformationLoss_weighted: -0.0319 - loss/label_L2_Distance: 12.4560 - loss/label_L2_Distance_weighted: 0.1246 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 2.3142e-07 - val_loss/regularization_BendingEnergy_weighted: 1.1571e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4081 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 15/4000
# 8/8 [==============================] - 40s 5s/step - loss: 0.0942 - loss/regularization_BendingEnergy: 4.3407e-05 - loss/regularization_BendingEnergy_weighted: 2.1704e-05 - loss/image_GlobalMutualInformationLoss: -0.0596 - loss/image_GlobalMutualInformationLoss_weighted: -0.0298 - loss/label_L2_Distance: 12.3990 - loss/label_L2_Distance_weighted: 0.1240 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.2743e-07 - val_loss/regularization_BendingEnergy_weighted: 1.1371e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4145 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 16/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.0854 - loss/regularization_BendingEnergy: 5.7253e-05 - loss/regularization_BendingEnergy_weighted: 2.8627e-05 - loss/image_GlobalMutualInformationLoss: -0.0486 - loss/image_GlobalMutualInformationLoss_weighted: -0.0243 - loss/label_L2_Distance: 10.9651 - loss/label_L2_Distance_weighted: 0.1097 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.0764e-07 - val_loss/regularization_BendingEnergy_weighted: 1.0382e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4199 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 17/4000
# 8/8 [==============================] - 43s 5s/step - loss: 0.0496 - loss/regularization_BendingEnergy: 5.5502e-05 - loss/regularization_BendingEnergy_weighted: 2.7751e-05 - loss/image_GlobalMutualInformationLoss: -0.0447 - loss/image_GlobalMutualInformationLoss_weighted: -0.0224 - loss/label_L2_Distance: 7.1967 - loss/label_L2_Distance_weighted: 0.0720 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 1.9647e-07 - val_loss/regularization_BendingEnergy_weighted: 9.8237e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4223 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 18/4000
# 8/8 [==============================] - 48s 6s/step - loss: 0.0457 - loss/regularization_BendingEnergy: 5.5370e-05 - loss/regularization_BendingEnergy_weighted: 2.7685e-05 - loss/image_GlobalMutualInformationLoss: -0.0665 - loss/image_GlobalMutualInformationLoss_weighted: -0.0333 - loss/label_L2_Distance: 7.8964 - loss/label_L2_Distance_weighted: 0.0790 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 1.9774e-07 - val_loss/regularization_BendingEnergy_weighted: 9.8872e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4217 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 19/4000
# 8/8 [==============================] - 47s 6s/step - loss: 0.0613 - loss/regularization_BendingEnergy: 5.3131e-05 - loss/regularization_BendingEnergy_weighted: 2.6565e-05 - loss/image_GlobalMutualInformationLoss: -0.0484 - loss/image_GlobalMutualInformationLoss_weighted: -0.0242 - loss/label_L2_Distance: 8.5455 - loss/label_L2_Distance_weighted: 0.0855 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 2.1116e-07 - val_loss/regularization_BendingEnergy_weighted: 1.0558e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4199 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 20/4000
# 8/8 [==============================] - 37s 5s/step - loss: 0.0435 - loss/regularization_BendingEnergy: 6.4793e-05 - loss/regularization_BendingEnergy_weighted: 3.2397e-05 - loss/image_GlobalMutualInformationLoss: -0.0522 - loss/image_GlobalMutualInformationLoss_weighted: -0.0261 - loss/label_L2_Distance: 6.9561 - loss/label_L2_Distance_weighted: 0.0696 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.3173e-07 - val_loss/regularization_BendingEnergy_weighted: 1.1587e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4187 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 21/4000
# 8/8 [==============================] - 47s 6s/step - loss: 0.0402 - loss/regularization_BendingEnergy: 7.5070e-05 - loss/regularization_BendingEnergy_weighted: 3.7535e-05 - loss/image_GlobalMutualInformationLoss: -0.0462 - loss/image_GlobalMutualInformationLoss_weighted: -0.0231 - loss/label_L2_Distance: 6.3296 - loss/label_L2_Distance_weighted: 0.0633 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.4288e-07 - val_loss/regularization_BendingEnergy_weighted: 1.2144e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4167 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 22/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0819 - loss/regularization_BendingEnergy: 7.8482e-05 - loss/regularization_BendingEnergy_weighted: 3.9241e-05 - loss/image_GlobalMutualInformationLoss: -0.0525 - loss/image_GlobalMutualInformationLoss_weighted: -0.0262 - loss/label_L2_Distance: 10.8051 - loss/label_L2_Distance_weighted: 0.1081 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.5205e-07 - val_loss/regularization_BendingEnergy_weighted: 1.2603e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4159 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 23/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1914 - loss/regularization_BendingEnergy: 8.2860e-05 - loss/regularization_BendingEnergy_weighted: 4.1430e-05 - loss/image_GlobalMutualInformationLoss: -0.0353 - loss/image_GlobalMutualInformationLoss_weighted: -0.0177 - loss/label_L2_Distance: 20.9056 - loss/label_L2_Distance_weighted: 0.2091 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.5895e-07 - val_loss/regularization_BendingEnergy_weighted: 1.2947e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4177 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 24/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0777 - loss/regularization_BendingEnergy: 8.8314e-05 - loss/regularization_BendingEnergy_weighted: 4.4157e-05 - loss/image_GlobalMutualInformationLoss: -0.0331 - loss/image_GlobalMutualInformationLoss_weighted: -0.0165 - loss/label_L2_Distance: 9.4191 - loss/label_L2_Distance_weighted: 0.0942 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 2.5903e-07 - val_loss/regularization_BendingEnergy_weighted: 1.2952e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4207 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 25/4000
# 8/8 [==============================] - 45s 6s/step - loss: 0.1609 - loss/regularization_BendingEnergy: 9.4020e-05 - loss/regularization_BendingEnergy_weighted: 4.7010e-05 - loss/image_GlobalMutualInformationLoss: -0.0656 - loss/image_GlobalMutualInformationLoss_weighted: -0.0328 - loss/label_L2_Distance: 19.3613 - loss/label_L2_Distance_weighted: 0.1936 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 2.5831e-07 - val_loss/regularization_BendingEnergy_weighted: 1.2916e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4229 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 26/4000
# 8/8 [==============================] - 52s 7s/step - loss: 0.0637 - loss/regularization_BendingEnergy: 1.1405e-04 - loss/regularization_BendingEnergy_weighted: 5.7027e-05 - loss/image_GlobalMutualInformationLoss: -0.0483 - loss/image_GlobalMutualInformationLoss_weighted: -0.0241 - loss/label_L2_Distance: 8.7815 - loss/label_L2_Distance_weighted: 0.0878 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 2.9648e-07 - val_loss/regularization_BendingEnergy_weighted: 1.4824e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4142 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 27/4000
# ...
# Epoch 73/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0106 - loss/regularization_BendingEnergy: 2.5343e-04 - loss/regularization_BendingEnergy_weighted: 1.2672e-04 - loss/image_GlobalMutualInformationLoss: -0.0819 - loss/image_GlobalMutualInformationLoss_weighted: -0.0410 - loss/label_L2_Distance: 5.1477 - loss/label_L2_Distance_weighted: 0.0515 - val_loss: 0.0224 - val_loss/regularization_BendingEnergy: 4.4623e-05 - val_loss/regularization_BendingEnergy_weighted: 2.2312e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0584 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0292 - val_loss/label_L2_Distance: 5.1600 - val_loss/label_L2_Distance_weighted: 0.0516
# Epoch 74/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0390 - loss/regularization_BendingEnergy: 2.5704e-04 - loss/regularization_BendingEnergy_weighted: 1.2852e-04 - loss/image_GlobalMutualInformationLoss: -0.0382 - loss/image_GlobalMutualInformationLoss_weighted: -0.0191 - loss/label_L2_Distance: 5.8001 - loss/label_L2_Distance_weighted: 0.0580 - val_loss: 0.0347 - val_loss/regularization_BendingEnergy: 6.6021e-05 - val_loss/regularization_BendingEnergy_weighted: 3.3011e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0587 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0293 - val_loss/label_L2_Distance: 6.3979 - val_loss/label_L2_Distance_weighted: 0.0640
# Epoch 75/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0636 - loss/regularization_BendingEnergy: 2.4696e-04 - loss/regularization_BendingEnergy_weighted: 1.2348e-04 - loss/image_GlobalMutualInformationLoss: -0.0446 - loss/image_GlobalMutualInformationLoss_weighted: -0.0223 - loss/label_L2_Distance: 8.5786 - loss/label_L2_Distance_weighted: 0.0858 - val_loss: 0.0417 - val_loss/regularization_BendingEnergy: 9.0334e-05 - val_loss/regularization_BendingEnergy_weighted: 4.5167e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 7.1248 - val_loss/label_L2_Distance_weighted: 0.0712
# Epoch 76/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0648 - loss/regularization_BendingEnergy: 2.1989e-04 - loss/regularization_BendingEnergy_weighted: 1.0995e-04 - loss/image_GlobalMutualInformationLoss: -0.0541 - loss/image_GlobalMutualInformationLoss_weighted: -0.0271 - loss/label_L2_Distance: 9.1760 - loss/label_L2_Distance_weighted: 0.0918 - val_loss: 0.0239 - val_loss/regularization_BendingEnergy: 5.2448e-05 - val_loss/regularization_BendingEnergy_weighted: 2.6224e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0593 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0297 - val_loss/label_L2_Distance: 5.3570 - val_loss/label_L2_Distance_weighted: 0.0536
# Epoch 77/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.2134 - loss/regularization_BendingEnergy: 3.1590e-04 - loss/regularization_BendingEnergy_weighted: 1.5795e-04 - loss/image_GlobalMutualInformationLoss: -0.0552 - loss/image_GlobalMutualInformationLoss_weighted: -0.0276 - loss/label_L2_Distance: 24.0821 - loss/label_L2_Distance_weighted: 0.2408 - val_loss: 0.0150 - val_loss/regularization_BendingEnergy: 3.7310e-05 - val_loss/regularization_BendingEnergy_weighted: 1.8655e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0589 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 4.4443 - val_loss/label_L2_Distance_weighted: 0.0444
# Epoch 78/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1477 - loss/regularization_BendingEnergy: 2.9517e-04 - loss/regularization_BendingEnergy_weighted: 1.4759e-04 - loss/image_GlobalMutualInformationLoss: -0.0655 - loss/image_GlobalMutualInformationLoss_weighted: -0.0327 - loss/label_L2_Distance: 18.0273 - loss/label_L2_Distance_weighted: 0.1803 - val_loss: 0.0152 - val_loss/regularization_BendingEnergy: 4.0451e-05 - val_loss/regularization_BendingEnergy_weighted: 2.0226e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0587 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0294 - val_loss/label_L2_Distance: 4.4552 - val_loss/label_L2_Distance_weighted: 0.0446
# Epoch 79/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0588 - loss/regularization_BendingEnergy: 2.6683e-04 - loss/regularization_BendingEnergy_weighted: 1.3341e-04 - loss/image_GlobalMutualInformationLoss: -0.0451 - loss/image_GlobalMutualInformationLoss_weighted: -0.0226 - loss/label_L2_Distance: 8.1239 - loss/label_L2_Distance_weighted: 0.0812 - val_loss: 0.0435 - val_loss/regularization_BendingEnergy: 1.0895e-04 - val_loss/regularization_BendingEnergy_weighted: 5.4477e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0589 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 7.2881 - val_loss/label_L2_Distance_weighted: 0.0729
# Epoch 80/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0676 - loss/regularization_BendingEnergy: 2.4035e-04 - loss/regularization_BendingEnergy_weighted: 1.2018e-04 - loss/image_GlobalMutualInformationLoss: -0.0593 - loss/image_GlobalMutualInformationLoss_weighted: -0.0297 - loss/label_L2_Distance: 9.7132 - loss/label_L2_Distance_weighted: 0.0971 - val_loss: 0.0579 - val_loss/regularization_BendingEnergy: 1.5009e-04 - val_loss/regularization_BendingEnergy_weighted: 7.5043e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 8.7367 - val_loss/label_L2_Distance_weighted: 0.0874
# Epoch 81/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0387 - loss/regularization_BendingEnergy: 2.3054e-04 - loss/regularization_BendingEnergy_weighted: 1.1527e-04 - loss/image_GlobalMutualInformationLoss: -0.0636 - loss/image_GlobalMutualInformationLoss_weighted: -0.0318 - loss/label_L2_Distance: 7.0373 - loss/label_L2_Distance_weighted: 0.0704 - val_loss: 0.0570 - val_loss/regularization_BendingEnergy: 1.5813e-04 - val_loss/regularization_BendingEnergy_weighted: 7.9067e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 8.6495 - val_loss/label_L2_Distance_weighted: 0.0865
# Epoch 82/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0231 - loss/regularization_BendingEnergy: 2.6881e-04 - loss/regularization_BendingEnergy_weighted: 1.3441e-04 - loss/image_GlobalMutualInformationLoss: -0.0717 - loss/image_GlobalMutualInformationLoss_weighted: -0.0358 - loss/label_L2_Distance: 5.8802 - loss/label_L2_Distance_weighted: 0.0588 - val_loss: 0.0549 - val_loss/regularization_BendingEnergy: 1.4533e-04 - val_loss/regularization_BendingEnergy_weighted: 7.2667e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 8.4362 - val_loss/label_L2_Distance_weighted: 0.0844
# Epoch 83/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0519 - loss/regularization_BendingEnergy: 2.6853e-04 - loss/regularization_BendingEnergy_weighted: 1.3426e-04 - loss/image_GlobalMutualInformationLoss: -0.0420 - loss/image_GlobalMutualInformationLoss_weighted: -0.0210 - loss/label_L2_Distance: 7.2756 - loss/label_L2_Distance_weighted: 0.0728 - val_loss: 0.0539 - val_loss/regularization_BendingEnergy: 1.2586e-04 - val_loss/regularization_BendingEnergy_weighted: 6.2930e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 8.3335 - val_loss/label_L2_Distance_weighted: 0.0833
# Epoch 84/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0295 - loss/regularization_BendingEnergy: 2.4320e-04 - loss/regularization_BendingEnergy_weighted: 1.2160e-04 - loss/image_GlobalMutualInformationLoss: -0.0444 - loss/image_GlobalMutualInformationLoss_weighted: -0.0222 - loss/label_L2_Distance: 5.1539 - loss/label_L2_Distance_weighted: 0.0515 - val_loss: 0.0508 - val_loss/regularization_BendingEnergy: 1.3656e-04 - val_loss/regularization_BendingEnergy_weighted: 6.8281e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0594 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0297 - val_loss/label_L2_Distance: 8.0426 - val_loss/label_L2_Distance_weighted: 0.0804
# Epoch 85/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0872 - loss/regularization_BendingEnergy: 2.6362e-04 - loss/regularization_BendingEnergy_weighted: 1.3181e-04 - loss/image_GlobalMutualInformationLoss: -0.0600 - loss/image_GlobalMutualInformationLoss_weighted: -0.0300 - loss/label_L2_Distance: 11.7066 - loss/label_L2_Distance_weighted: 0.1171 - val_loss: 0.0549 - val_loss/regularization_BendingEnergy: 1.6042e-04 - val_loss/regularization_BendingEnergy_weighted: 8.0208e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0596 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0298 - val_loss/label_L2_Distance: 8.4578 - val_loss/label_L2_Distance_weighted: 0.0846
# Epoch 86/4000
# 8/8 [==============================] - 37s 5s/step - loss: 0.1443 - loss/regularization_BendingEnergy: 3.1312e-04 - loss/regularization_BendingEnergy_weighted: 1.5656e-04 - loss/image_GlobalMutualInformationLoss: -0.0536 - loss/image_GlobalMutualInformationLoss_weighted: -0.0268 - loss/label_L2_Distance: 17.0957 - loss/label_L2_Distance_weighted: 0.1710 - val_loss: 0.0539 - val_loss/regularization_BendingEnergy: 1.5997e-04 - val_loss/regularization_BendingEnergy_weighted: 7.9985e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0593 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0297 - val_loss/label_L2_Distance: 8.3431 - val_loss/label_L2_Distance_weighted: 0.0834
# Epoch 87/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0495 - loss/regularization_BendingEnergy: 3.0293e-04 - loss/regularization_BendingEnergy_weighted: 1.5146e-04 - loss/image_GlobalMutualInformationLoss: -0.0457 - loss/image_GlobalMutualInformationLoss_weighted: -0.0229 - loss/label_L2_Distance: 7.2192 - loss/label_L2_Distance_weighted: 0.0722 - val_loss: 0.0639 - val_loss/regularization_BendingEnergy: 1.9477e-04 - val_loss/regularization_BendingEnergy_weighted: 9.7387e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 9.3381 - val_loss/label_L2_Distance_weighted: 0.0934
# Epoch 88/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0558 - loss/regularization_BendingEnergy: 3.1107e-04 - loss/regularization_BendingEnergy_weighted: 1.5554e-04 - loss/image_GlobalMutualInformationLoss: -0.0381 - loss/image_GlobalMutualInformationLoss_weighted: -0.0191 - loss/label_L2_Distance: 7.4706 - loss/label_L2_Distance_weighted: 0.0747 - val_loss: 0.0478 - val_loss/regularization_BendingEnergy: 1.7127e-04 - val_loss/regularization_BendingEnergy_weighted: 8.5635e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 7.7298 - val_loss/label_L2_Distance_weighted: 0.0773
# Epoch 89/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0508 - loss/regularization_BendingEnergy: 3.2286e-04 - loss/regularization_BendingEnergy_weighted: 1.6143e-04 - loss/image_GlobalMutualInformationLoss: -0.0493 - loss/image_GlobalMutualInformationLoss_weighted: -0.0247 - loss/label_L2_Distance: 7.5288 - loss/label_L2_Distance_weighted: 0.0753 - val_loss: 0.0464 - val_loss/regularization_BendingEnergy: 2.0268e-04 - val_loss/regularization_BendingEnergy_weighted: 1.0134e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 7.5830 - val_loss/label_L2_Distance_weighted: 0.0758
# Epoch 90/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1487 - loss/regularization_BendingEnergy: 3.0701e-04 - loss/regularization_BendingEnergy_weighted: 1.5351e-04 - loss/image_GlobalMutualInformationLoss: -0.0431 - loss/image_GlobalMutualInformationLoss_weighted: -0.0216 - loss/label_L2_Distance: 17.0152 - loss/label_L2_Distance_weighted: 0.1702 - val_loss: 0.0928 - val_loss/regularization_BendingEnergy: 3.8302e-04 - val_loss/regularization_BendingEnergy_weighted: 1.9151e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 12.2191 - val_loss/label_L2_Distance_weighted: 0.1222
# Epoch 91/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0836 - loss/regularization_BendingEnergy: 2.8628e-04 - loss/regularization_BendingEnergy_weighted: 1.4314e-04 - loss/image_GlobalMutualInformationLoss: -0.0812 - loss/image_GlobalMutualInformationLoss_weighted: -0.0406 - loss/label_L2_Distance: 12.4022 - loss/label_L2_Distance_weighted: 0.1240 - val_loss: 0.1176 - val_loss/regularization_BendingEnergy: 4.9698e-04 - val_loss/regularization_BendingEnergy_weighted: 2.4849e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 14.6901 - val_loss/label_L2_Distance_weighted: 0.1469
# Epoch 92/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0325 - loss/regularization_BendingEnergy: 2.9264e-04 - loss/regularization_BendingEnergy_weighted: 1.4632e-04 - loss/image_GlobalMutualInformationLoss: -0.0599 - loss/image_GlobalMutualInformationLoss_weighted: -0.0300 - loss/label_L2_Distance: 6.2275 - loss/label_L2_Distance_weighted: 0.0623 - val_loss: 0.1223 - val_loss/regularization_BendingEnergy: 5.2239e-04 - val_loss/regularization_BendingEnergy_weighted: 2.6120e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0592 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 15.1649 - val_loss/label_L2_Distance_weighted: 0.1516
# Epoch 93/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0385 - loss/regularization_BendingEnergy: 2.7913e-04 - loss/regularization_BendingEnergy_weighted: 1.3956e-04 - loss/image_GlobalMutualInformationLoss: -0.0365 - loss/image_GlobalMutualInformationLoss_weighted: -0.0182 - loss/label_L2_Distance: 5.6573 - loss/label_L2_Distance_weighted: 0.0566 - val_loss: 0.1060 - val_loss/regularization_BendingEnergy: 4.4896e-04 - val_loss/regularization_BendingEnergy_weighted: 2.2448e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 13.5332 - val_loss/label_L2_Distance_weighted: 0.1353
# Epoch 94/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0125 - loss/regularization_BendingEnergy: 2.8553e-04 - loss/regularization_BendingEnergy_weighted: 1.4276e-04 - loss/image_GlobalMutualInformationLoss: -0.0945 - loss/image_GlobalMutualInformationLoss_weighted: -0.0473 - loss/label_L2_Distance: 5.9616 - loss/label_L2_Distance_weighted: 0.0596 - val_loss: 0.0828 - val_loss/regularization_BendingEnergy: 3.3056e-04 - val_loss/regularization_BendingEnergy_weighted: 1.6528e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0586 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0293 - val_loss/label_L2_Distance: 11.1952 - val_loss/label_L2_Distance_weighted: 0.1120

# %%
min(history.history['val_loss/label_L2_Distance'])
# Out:
# 2.132871627807617

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss/label_L2_Distance'], label = 'Training Loss')
plt.plot(history.history['val_loss/label_L2_Distance'], label = 'Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('L2 Loss')
# Out:
# Text(0, 0.5, 'L2 Loss')

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_loss/label_L2_Distance'][:45], 'orange', label = 'Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('L2 Loss')
# Out:
# Text(0, 0.5, 'L2 Loss')

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss/label_L2_Distance'][:45], label = 'Training Loss')
plt.plot(history.history['val_loss/label_L2_Distance'][:45], label = 'Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('L2 Loss')
# Out:
# Text(0, 0.5, 'L2 Loss')

# %%
import argparse
from datetime import datetime

from deepreg.train import train

name = "paired_mrus_brain"

log_dir = "logs_train/" + datetime.now().strftime("%Y%m%d-%H%M%S")
config_path = [f"{name}.yaml"]

# %%
history = train(
    gpu="0", 
    config_path=config_path,
    gpu_allow_growth=False,
    ckpt_path="",
    log_dir=log_dir
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-cf12de395814> in <module>
#       5     ckpt_path="",
#       6     log_dir=log_dir,
# ----> 7     exp_name="Final_Run"
#       8 )
#
# TypeError: train() got an unexpected keyword argument 'exp_name'

# %%
import argparse
from datetime import datetime

from deepreg.train import train

name = "paired_mrus_brain"

log_root = f""
log_dir = "logs_train/" + datetime.now().strftime("%Y%m%d-%H%M%S")
config_path = [f"{name}.yaml"]

# %%
history = train(
    gpu="0", 
    config_path=config_path,
    gpu_allow_growth=False,
    ckpt_path="",
    log_dir=log_dir,
)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# moving_image (InputLayer)       [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(2, 151, 136, 119,  0           moving_image[0][0]
# __________________________________________________________________________________________________
# fixed_image (InputLayer)        [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# resize3d (Resize3d)             (2, 151, 136, 119, 1 0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_1 (Tenso [(2, 151, 136, 119,  0           fixed_image[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(2, 151, 136, 119,  0           resize3d[0][0]
#                                                                  tf_op_layer_ExpandDims_1[0][0]
# __________________________________________________________________________________________________
# LocalNet (LocalNet)             (2, 151, 136, 119, 3 1502236     tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# moving_label (InputLayer)       [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# fixed_label (InputLayer)        [(2, 151, 136, 119)] 0
# __________________________________________________________________________________________________
# indices (InputLayer)            [(2, 2)]             0
# __________________________________________________________________________________________________
# warping (Warping)               (2, 151, 136, 119)   0           LocalNet[0][0]
#                                                                  moving_image[0][0]
#                                                                  LocalNet[0][0]
#                                                                  moving_label[0][0]
# __________________________________________________________________________________________________
# BendingEnergy (BendingEnergy)   ()                   0           LocalNet[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [()]                 0           BendingEnergy[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [()]                 0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# add_metric_1 (AddMetric)        ()                   0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_2 (Tenso [(2, 151, 136, 119,  0           fixed_image[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value/Minim [(2, 151, 136, 119,  0           tf_op_layer_ExpandDims_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_3 (Tenso [(2, 151, 136, 119,  0           warping[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value (Tens [(2, 151, 136, 119,  0           tf_op_layer_clip_by_value/Minimum
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value_1/Min [(2, 151, 136, 119,  0           tf_op_layer_ExpandDims_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(2, 2443784, 1)]    0           tf_op_layer_clip_by_value[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_clip_by_value_1 (Te [(2, 151, 136, 119,  0           tf_op_layer_clip_by_value_1/Minim
# __________________________________________________________________________________________________
# tf_op_layer_sub_1 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1 (TensorFl [(2, 2443784, 1)]    0           tf_op_layer_clip_by_value_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(2, 2443784, 23)]   0           tf_op_layer_sub_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_2 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Reshape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_3 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_2 (TensorFlo [(2, 2443784, 23)]   0           tf_op_layer_sub_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(2, 2443784, 23)]   0           tf_op_layer_mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_4 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_Square_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(2, 2443784, 1)]    0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(2, 2443784, 23)]   0           tf_op_layer_mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_1 (TensorFl [(2, 2443784, 23)]   0           tf_op_layer_Exp[0][0]
#                                                                  tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_1 (TensorFlowOp [(2, 2443784, 1)]    0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose (TensorFl [(2, 23, 2443784)]   0           tf_op_layer_truediv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_2 (TensorFl [(2, 2443784, 23)]   0           tf_op_layer_Exp_1[0][0]
#                                                                  tf_op_layer_Sum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_1 (TensorFlo [(2, 23, 23)]        0           tf_op_layer_transpose[0][0]
#                                                                  tf_op_layer_truediv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [(2, 23, 1)]         0           tf_op_layer_transpose[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_2 (TensorFlowO [(2, 1, 23)]         0           tf_op_layer_truediv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_3 (TensorFl [(2, 23, 23)]        0           tf_op_layer_MatMul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul (TensorFlowO [(2, 23, 23)]        0           tf_op_layer_Mean_1[0][0]
#                                                                  tf_op_layer_Mean_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(2, 23, 23)]        0           tf_op_layer_truediv_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_1 (TensorFlowOp [(2, 23, 23)]        0           tf_op_layer_MatMul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_4 (TensorFl [(2, 23, 23)]        0           tf_op_layer_add[0][0]
#                                                                  tf_op_layer_add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_2 (TensorFlowOp [(2, 23, 23)]        0           tf_op_layer_truediv_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(2, 23, 23)]        0           tf_op_layer_add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_5 (TensorFlowOp [(2, 23, 23)]        0           tf_op_layer_truediv_3[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_2 (TensorFlowOp [(2,)]               0           tf_op_layer_mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg_2 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss/Mul ( [(2,)]               0           tf_op_layer_Neg_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss/Sum ( [()]                 0           tf_op_layer_weighted_loss/Mul[0][
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [()]                 0           tf_op_layer_weighted_loss/Sum[0][
# __________________________________________________________________________________________________
# tf_op_layer_Mul_6 (TensorFlowOp [()]                 0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# add_loss_1 (AddLoss)            ()                   0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# add_metric_2 (AddMetric)        ()                   0           tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# add_metric_3 (AddMetric)        ()                   0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_5 (Tensor [(2, 119, 136, 151)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_6 (Tensor [(2, 119, 136, 151)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_1 (Tensor [(2, 119, 136, 151)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_2 (Tensor [(2, 119, 136, 151)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_7 (Tensor [(2, 151, 119, 136)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_8 (Tensor [(2, 151, 119, 136)] 0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_3 (Tensor [(2, 151, 119, 136)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_4 (Tensor [(2, 151, 119, 136)] 0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_8 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_9 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_2 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_3 (TensorFlo [(2, 119, 136, 1)]   0           tf_op_layer_transpose_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_10 (TensorFl [(2, 151, 119, 1)]   0           tf_op_layer_transpose_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_11 (TensorFl [(2, 151, 119, 1)]   0           tf_op_layer_transpose_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_4 (TensorFlo [(2, 151, 119, 1)]   0           tf_op_layer_transpose_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_5 (TensorFlo [(2, 151, 119, 1)]   0           tf_op_layer_transpose_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_9 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_10 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_3 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_4 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_11 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_12 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_5 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_6 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_12 (TensorFl [(2, 151, 136, 1)]   0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_13 (TensorFl [(2, 151, 136, 1)]   0           warping[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_6 (TensorFlo [(2, 151, 136, 1)]   0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_matmul_7 (TensorFlo [(2, 151, 136, 1)]   0           fixed_label[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_9 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_10 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_3 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_4 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_11 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_12 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_5 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_6 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_13 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_14 (TensorFlowO [(2,)]               0           tf_op_layer_matmul_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_7 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_8 (TensorFlowOp [(2,)]               0           tf_op_layer_matmul_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_8 (TensorFl [(2,)]               0           tf_op_layer_add_9[0][0]
#                                                                  tf_op_layer_add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_5 (TensorFl [(2,)]               0           tf_op_layer_add_3[0][0]
#                                                                  tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_9 (TensorFl [(2,)]               0           tf_op_layer_add_11[0][0]
#                                                                  tf_op_layer_add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_6 (TensorFl [(2,)]               0           tf_op_layer_add_5[0][0]
#                                                                  tf_op_layer_add_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_13 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_14 (TensorFlowO [(2,)]               0           tf_op_layer_Sum_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_7 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_8 (TensorFlowOp [(2,)]               0           tf_op_layer_Sum_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_3 (TensorFlowOp [(2,)]               0           tf_op_layer_truediv_8[0][0]
#                                                                  tf_op_layer_truediv_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_4 (TensorFlowOp [(2,)]               0           tf_op_layer_truediv_9[0][0]
#                                                                  tf_op_layer_truediv_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_10 (TensorF [(2,)]               0           tf_op_layer_add_13[0][0]
#                                                                  tf_op_layer_add_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_7 (TensorFl [(2,)]               0           tf_op_layer_add_7[0][0]
#                                                                  tf_op_layer_add_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow (TensorFlowOpLa [(2,)]               0           tf_op_layer_sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow_1 (TensorFlowOp [(2,)]               0           tf_op_layer_sub_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_5 (TensorFlowOp [(2,)]               0           tf_op_layer_truediv_10[0][0]
#                                                                  tf_op_layer_truediv_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_15 (TensorFlowO [(2,)]               0           tf_op_layer_pow[0][0]
#                                                                  tf_op_layer_pow_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow_2 (TensorFlowOp [(2,)]               0           tf_op_layer_sub_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_16 (TensorFlowO [(2,)]               0           tf_op_layer_add_15[0][0]
#                                                                  tf_op_layer_pow_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(2,)]               0           tf_op_layer_add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss_1/Mul [(2,)]               0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_weighted_loss_1/Sum [()]                 0           tf_op_layer_weighted_loss_1/Mul[0
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_2 (TensorFl [()]                 0           tf_op_layer_weighted_loss_1/Sum[0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_7 (TensorFlowOp [()]                 0           tf_op_layer_RealDiv_2[0][0]
# __________________________________________________________________________________________________
# add_loss_2 (AddLoss)            ()                   0           tf_op_layer_Mul_7[0][0]
# __________________________________________________________________________________________________
# add_metric_4 (AddMetric)        ()                   0           tf_op_layer_RealDiv_2[0][0]
# __________________________________________________________________________________________________
# add_metric_5 (AddMetric)        ()                   0           tf_op_layer_Mul_7[0][0]
# ==================================================================================================
# Total params: 1,502,236
# Trainable params: 1,500,412
# Non-trainable params: 1,824
# __________________________________________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0606 - loss/regularization_BendingEnergy: 0.0000e+00 - loss/regularization_BendingEnergy_weighted: 0.0000e+00 - loss/image_GlobalMutualInformationLoss: -0.0388 - loss/image_GlobalMutualInformationLoss_weighted: -0.0194 - loss/label_L2_Distance: 7.9994 - loss/label_L2_Distance_weighted: 0.0800
# Epoch 1/4000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0562 - loss/regularization_BendingEnergy: 4.8265e-09 - loss/regularization_BendingEnergy_weighted: 2.4132e-09 - loss/image_GlobalMutualInformationLoss: -0.0541 - loss/image_GlobalMutualInformationLoss_weighted: -0.0271 - loss/label_L2_Distance: 8.3294 - loss/label_L2_Distance_weighted: 0.0833WARNING:tensorflow:From /home/dmanwill/anaconda3/envs/MMIR/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:From /home/dmanwill/anaconda3/envs/MMIR/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 2/8 [======>.......................] - ETA: 29s - loss: 0.0651 - loss/regularization_BendingEnergy: 1.0897e-08 - loss/regularization_BendingEnergy_weighted: 5.4483e-09 - loss/image_GlobalMutualInformationLoss: -0.0541 - loss/image_GlobalMutualInformationLoss_weighted: -0.0271 - loss/label_L2_Distance: 9.2151 - loss/label_L2_Distance_weighted: 0.0922WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 3.4949s vs `on_train_batch_end` time: 6.1819s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 3.4949s vs `on_train_batch_end` time: 6.1819s). Check your callbacks.
# 8/8 [==============================] - 54s 7s/step - loss: 0.1571 - loss/regularization_BendingEnergy: 7.3481e-08 - loss/regularization_BendingEnergy_weighted: 3.6740e-08 - loss/image_GlobalMutualInformationLoss: -0.0541 - loss/image_GlobalMutualInformationLoss_weighted: -0.0270 - loss/label_L2_Distance: 18.4134 - loss/label_L2_Distance_weighted: 0.1841 - val_loss: -0.0043 - val_loss/regularization_BendingEnergy: 2.5458e-10 - val_loss/regularization_BendingEnergy_weighted: 1.2729e-10 - val_loss/image_GlobalMutualInformationLoss: -0.0574 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0287 - val_loss/label_L2_Distance: 2.4351 - val_loss/label_L2_Distance_weighted: 0.0244
# Epoch 2/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.0438 - loss/regularization_BendingEnergy: 3.4292e-07 - loss/regularization_BendingEnergy_weighted: 1.7146e-07 - loss/image_GlobalMutualInformationLoss: -0.0480 - loss/image_GlobalMutualInformationLoss_weighted: -0.0240 - loss/label_L2_Distance: 6.7813 - loss/label_L2_Distance_weighted: 0.0678 - val_loss: -0.0046 - val_loss/regularization_BendingEnergy: 1.2200e-09 - val_loss/regularization_BendingEnergy_weighted: 6.1001e-10 - val_loss/image_GlobalMutualInformationLoss: -0.0579 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4334 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 3/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0963 - loss/regularization_BendingEnergy: 7.5981e-07 - loss/regularization_BendingEnergy_weighted: 3.7990e-07 - loss/image_GlobalMutualInformationLoss: -0.0528 - loss/image_GlobalMutualInformationLoss_weighted: -0.0264 - loss/label_L2_Distance: 12.2721 - loss/label_L2_Distance_weighted: 0.1227 - val_loss: -0.0047 - val_loss/regularization_BendingEnergy: 4.0151e-09 - val_loss/regularization_BendingEnergy_weighted: 2.0075e-09 - val_loss/image_GlobalMutualInformationLoss: -0.0580 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4317 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 4/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.0643 - loss/regularization_BendingEnergy: 1.5560e-06 - loss/regularization_BendingEnergy_weighted: 7.7799e-07 - loss/image_GlobalMutualInformationLoss: -0.0476 - loss/image_GlobalMutualInformationLoss_weighted: -0.0238 - loss/label_L2_Distance: 8.8100 - loss/label_L2_Distance_weighted: 0.0881 - val_loss: -0.0047 - val_loss/regularization_BendingEnergy: 1.1229e-08 - val_loss/regularization_BendingEnergy_weighted: 5.6144e-09 - val_loss/image_GlobalMutualInformationLoss: -0.0580 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4288 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 5/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.0575 - loss/regularization_BendingEnergy: 2.4156e-06 - loss/regularization_BendingEnergy_weighted: 1.2078e-06 - loss/image_GlobalMutualInformationLoss: -0.0706 - loss/image_GlobalMutualInformationLoss_weighted: -0.0353 - loss/label_L2_Distance: 9.2812 - loss/label_L2_Distance_weighted: 0.0928 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 2.4042e-08 - val_loss/regularization_BendingEnergy_weighted: 1.2021e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0580 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4263 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 6/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0843 - loss/regularization_BendingEnergy: 3.6248e-06 - loss/regularization_BendingEnergy_weighted: 1.8124e-06 - loss/image_GlobalMutualInformationLoss: -0.0461 - loss/image_GlobalMutualInformationLoss_weighted: -0.0231 - loss/label_L2_Distance: 10.7403 - loss/label_L2_Distance_weighted: 0.1074 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 3.8578e-08 - val_loss/regularization_BendingEnergy_weighted: 1.9289e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0290 - val_loss/label_L2_Distance: 2.4270 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 7/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0649 - loss/regularization_BendingEnergy: 5.0429e-06 - loss/regularization_BendingEnergy_weighted: 2.5215e-06 - loss/image_GlobalMutualInformationLoss: -0.0898 - loss/image_GlobalMutualInformationLoss_weighted: -0.0449 - loss/label_L2_Distance: 10.9833 - loss/label_L2_Distance_weighted: 0.1098 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 6.1071e-08 - val_loss/regularization_BendingEnergy_weighted: 3.0536e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4254 - val_loss/label_L2_Distance_weighted: 0.0243
# Epoch 8/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1575 - loss/regularization_BendingEnergy: 6.8251e-06 - loss/regularization_BendingEnergy_weighted: 3.4126e-06 - loss/image_GlobalMutualInformationLoss: -0.0367 - loss/image_GlobalMutualInformationLoss_weighted: -0.0183 - loss/label_L2_Distance: 17.5782 - loss/label_L2_Distance_weighted: 0.1758 - val_loss: -0.0048 - val_loss/regularization_BendingEnergy: 7.9250e-08 - val_loss/regularization_BendingEnergy_weighted: 3.9625e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4223 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 9/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0542 - loss/regularization_BendingEnergy: 7.0630e-06 - loss/regularization_BendingEnergy_weighted: 3.5315e-06 - loss/image_GlobalMutualInformationLoss: -0.0398 - loss/image_GlobalMutualInformationLoss_weighted: -0.0199 - loss/label_L2_Distance: 7.4056 - loss/label_L2_Distance_weighted: 0.0741 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 9.4114e-08 - val_loss/regularization_BendingEnergy_weighted: 4.7057e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0581 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4193 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 10/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1023 - loss/regularization_BendingEnergy: 8.0889e-06 - loss/regularization_BendingEnergy_weighted: 4.0444e-06 - loss/image_GlobalMutualInformationLoss: -0.0466 - loss/image_GlobalMutualInformationLoss_weighted: -0.0233 - loss/label_L2_Distance: 12.5567 - loss/label_L2_Distance_weighted: 0.1256 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.1223e-07 - val_loss/regularization_BendingEnergy_weighted: 5.6115e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4177 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 11/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1559 - loss/regularization_BendingEnergy: 9.7547e-06 - loss/regularization_BendingEnergy_weighted: 4.8774e-06 - loss/image_GlobalMutualInformationLoss: -0.0540 - loss/image_GlobalMutualInformationLoss_weighted: -0.0270 - loss/label_L2_Distance: 18.2877 - loss/label_L2_Distance_weighted: 0.1829 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.3385e-07 - val_loss/regularization_BendingEnergy_weighted: 6.6926e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4177 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 12/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0495 - loss/regularization_BendingEnergy: 1.2594e-05 - loss/regularization_BendingEnergy_weighted: 6.2970e-06 - loss/image_GlobalMutualInformationLoss: -0.0412 - loss/image_GlobalMutualInformationLoss_weighted: -0.0206 - loss/label_L2_Distance: 7.0135 - loss/label_L2_Distance_weighted: 0.0701 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.6309e-07 - val_loss/regularization_BendingEnergy_weighted: 8.1543e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4185 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 13/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0672 - loss/regularization_BendingEnergy: 1.8783e-05 - loss/regularization_BendingEnergy_weighted: 9.3913e-06 - loss/image_GlobalMutualInformationLoss: -0.0499 - loss/image_GlobalMutualInformationLoss_weighted: -0.0250 - loss/label_L2_Distance: 9.2188 - loss/label_L2_Distance_weighted: 0.0922 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 1.8434e-07 - val_loss/regularization_BendingEnergy_weighted: 9.2169e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4140 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 14/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1509 - loss/regularization_BendingEnergy: 2.2993e-05 - loss/regularization_BendingEnergy_weighted: 1.1497e-05 - loss/image_GlobalMutualInformationLoss: -0.0577 - loss/image_GlobalMutualInformationLoss_weighted: -0.0289 - loss/label_L2_Distance: 17.9779 - loss/label_L2_Distance_weighted: 0.1798 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 2.1055e-07 - val_loss/regularization_BendingEnergy_weighted: 1.0527e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4105 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 15/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1228 - loss/regularization_BendingEnergy: 2.4035e-05 - loss/regularization_BendingEnergy_weighted: 1.2017e-05 - loss/image_GlobalMutualInformationLoss: -0.0606 - loss/image_GlobalMutualInformationLoss_weighted: -0.0303 - loss/label_L2_Distance: 15.3076 - loss/label_L2_Distance_weighted: 0.1531 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 2.0944e-07 - val_loss/regularization_BendingEnergy_weighted: 1.0472e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4081 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 16/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0861 - loss/regularization_BendingEnergy: 2.3924e-05 - loss/regularization_BendingEnergy_weighted: 1.1962e-05 - loss/image_GlobalMutualInformationLoss: -0.0459 - loss/image_GlobalMutualInformationLoss_weighted: -0.0230 - loss/label_L2_Distance: 10.9065 - loss/label_L2_Distance_weighted: 0.1091 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 1.9087e-07 - val_loss/regularization_BendingEnergy_weighted: 9.5435e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4118 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 17/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1554 - loss/regularization_BendingEnergy: 2.2882e-05 - loss/regularization_BendingEnergy_weighted: 1.1441e-05 - loss/image_GlobalMutualInformationLoss: -0.0536 - loss/image_GlobalMutualInformationLoss_weighted: -0.0268 - loss/label_L2_Distance: 18.2193 - loss/label_L2_Distance_weighted: 0.1822 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.8883e-07 - val_loss/regularization_BendingEnergy_weighted: 9.4416e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4164 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 18/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1215 - loss/regularization_BendingEnergy: 2.6049e-05 - loss/regularization_BendingEnergy_weighted: 1.3025e-05 - loss/image_GlobalMutualInformationLoss: -0.0573 - loss/image_GlobalMutualInformationLoss_weighted: -0.0287 - loss/label_L2_Distance: 15.0165 - loss/label_L2_Distance_weighted: 0.1502 - val_loss: -0.0049 - val_loss/regularization_BendingEnergy: 1.9719e-07 - val_loss/regularization_BendingEnergy_weighted: 9.8594e-08 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4164 - val_loss/label_L2_Distance_weighted: 0.0242
# Epoch 19/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0574 - loss/regularization_BendingEnergy: 2.8237e-05 - loss/regularization_BendingEnergy_weighted: 1.4119e-05 - loss/image_GlobalMutualInformationLoss: -0.0568 - loss/image_GlobalMutualInformationLoss_weighted: -0.0284 - loss/label_L2_Distance: 8.5820 - loss/label_L2_Distance_weighted: 0.0858 - val_loss: -0.0050 - val_loss/regularization_BendingEnergy: 2.1903e-07 - val_loss/regularization_BendingEnergy_weighted: 1.0952e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0582 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.4119 - val_loss/label_L2_Distance_weighted: 0.0241
# Epoch 20/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.1388 - loss/regularization_BendingEnergy: 3.5557e-05 - loss/regularization_BendingEnergy_weighted: 1.7779e-05 - loss/image_GlobalMutualInformationLoss: -0.0534 - loss/image_GlobalMutualInformationLoss_weighted: -0.0267 - loss/label_L2_Distance: 16.5493 - loss/label_L2_Distance_weighted: 0.1655 - val_loss: -0.0053 - val_loss/regularization_BendingEnergy: 2.8477e-07 - val_loss/regularization_BendingEnergy_weighted: 1.4239e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0583 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0291 - val_loss/label_L2_Distance: 2.3890 - val_loss/label_L2_Distance_weighted: 0.0239
# Epoch 21/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1630 - loss/regularization_BendingEnergy: 3.5144e-05 - loss/regularization_BendingEnergy_weighted: 1.7572e-05 - loss/image_GlobalMutualInformationLoss: -0.0384 - loss/image_GlobalMutualInformationLoss_weighted: -0.0192 - loss/label_L2_Distance: 18.2197 - loss/label_L2_Distance_weighted: 0.1822 - val_loss: -0.0056 - val_loss/regularization_BendingEnergy: 3.7992e-07 - val_loss/regularization_BendingEnergy_weighted: 1.8996e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0584 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0292 - val_loss/label_L2_Distance: 2.3597 - val_loss/label_L2_Distance_weighted: 0.0236
# Epoch 22/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0823 - loss/regularization_BendingEnergy: 3.9016e-05 - loss/regularization_BendingEnergy_weighted: 1.9508e-05 - loss/image_GlobalMutualInformationLoss: -0.0405 - loss/image_GlobalMutualInformationLoss_weighted: -0.0203 - loss/label_L2_Distance: 10.2521 - loss/label_L2_Distance_weighted: 0.1025 - val_loss: -0.0057 - val_loss/regularization_BendingEnergy: 4.2863e-07 - val_loss/regularization_BendingEnergy_weighted: 2.1431e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0584 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0292 - val_loss/label_L2_Distance: 2.3471 - val_loss/label_L2_Distance_weighted: 0.0235
# Epoch 23/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0751 - loss/regularization_BendingEnergy: 3.8952e-05 - loss/regularization_BendingEnergy_weighted: 1.9476e-05 - loss/image_GlobalMutualInformationLoss: -0.0604 - loss/image_GlobalMutualInformationLoss_weighted: -0.0302 - loss/label_L2_Distance: 10.5276 - loss/label_L2_Distance_weighted: 0.1053 - val_loss: -0.0057 - val_loss/regularization_BendingEnergy: 4.1847e-07 - val_loss/regularization_BendingEnergy_weighted: 2.0924e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0584 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0292 - val_loss/label_L2_Distance: 2.3503 - val_loss/label_L2_Distance_weighted: 0.0235
# Epoch 24/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0308 - loss/regularization_BendingEnergy: 3.3424e-05 - loss/regularization_BendingEnergy_weighted: 1.6712e-05 - loss/image_GlobalMutualInformationLoss: -0.0821 - loss/image_GlobalMutualInformationLoss_weighted: -0.0411 - loss/label_L2_Distance: 7.1825 - loss/label_L2_Distance_weighted: 0.0718 - val_loss: -0.0057 - val_loss/regularization_BendingEnergy: 4.5376e-07 - val_loss/regularization_BendingEnergy_weighted: 2.2688e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0584 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0292 - val_loss/label_L2_Distance: 2.3506 - val_loss/label_L2_Distance_weighted: 0.0235
# Epoch 25/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0123 - loss/regularization_BendingEnergy: 3.3502e-05 - loss/regularization_BendingEnergy_weighted: 1.6751e-05 - loss/image_GlobalMutualInformationLoss: -0.1055 - loss/image_GlobalMutualInformationLoss_weighted: -0.0527 - loss/label_L2_Distance: 6.4997 - loss/label_L2_Distance_weighted: 0.0650 - val_loss: -0.0058 - val_loss/regularization_BendingEnergy: 5.5775e-07 - val_loss/regularization_BendingEnergy_weighted: 2.7888e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0585 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0292 - val_loss/label_L2_Distance: 2.3406 - val_loss/label_L2_Distance_weighted: 0.0234
# Epoch 26/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0491 - loss/regularization_BendingEnergy: 3.8470e-05 - loss/regularization_BendingEnergy_weighted: 1.9235e-05 - loss/image_GlobalMutualInformationLoss: -0.0526 - loss/image_GlobalMutualInformationLoss_weighted: -0.0263 - loss/label_L2_Distance: 7.5420 - loss/label_L2_Distance_weighted: 0.0754 - val_loss: -0.0060 - val_loss/regularization_BendingEnergy: 6.7960e-07 - val_loss/regularization_BendingEnergy_weighted: 3.3980e-07 - val_loss/image_GlobalMutualInformationLoss: -0.0585 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0293 - val_loss/label_L2_Distance: 2.3221 - val_loss/label_L2_Distance_weighted: 0.0232
# Epoch 27/4000
# ...
# Epoch 55/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0240 - loss/regularization_BendingEnergy: 8.7287e-05 - loss/regularization_BendingEnergy_weighted: 4.3644e-05 - loss/image_GlobalMutualInformationLoss: -0.0548 - loss/image_GlobalMutualInformationLoss_weighted: -0.0274 - loss/label_L2_Distance: 5.1333 - loss/label_L2_Distance_weighted: 0.0513 - val_loss: 0.0356 - val_loss/regularization_BendingEnergy: 5.6806e-05 - val_loss/regularization_BendingEnergy_weighted: 2.8403e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0598 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0299 - val_loss/label_L2_Distance: 6.5480 - val_loss/label_L2_Distance_weighted: 0.0655
# Epoch 56/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0379 - loss/regularization_BendingEnergy: 9.4179e-05 - loss/regularization_BendingEnergy_weighted: 4.7089e-05 - loss/image_GlobalMutualInformationLoss: -0.0447 - loss/image_GlobalMutualInformationLoss_weighted: -0.0223 - loss/label_L2_Distance: 6.0197 - loss/label_L2_Distance_weighted: 0.0602 - val_loss: 0.0267 - val_loss/regularization_BendingEnergy: 4.9785e-05 - val_loss/regularization_BendingEnergy_weighted: 2.4892e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0603 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0302 - val_loss/label_L2_Distance: 5.6806 - val_loss/label_L2_Distance_weighted: 0.0568
# Epoch 57/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0415 - loss/regularization_BendingEnergy: 9.4371e-05 - loss/regularization_BendingEnergy_weighted: 4.7185e-05 - loss/image_GlobalMutualInformationLoss: -0.0562 - loss/image_GlobalMutualInformationLoss_weighted: -0.0281 - loss/label_L2_Distance: 6.9508 - loss/label_L2_Distance_weighted: 0.0695 - val_loss: 0.0192 - val_loss/regularization_BendingEnergy: 4.5578e-05 - val_loss/regularization_BendingEnergy_weighted: 2.2789e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0606 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0303 - val_loss/label_L2_Distance: 4.9474 - val_loss/label_L2_Distance_weighted: 0.0495
# Epoch 58/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0370 - loss/regularization_BendingEnergy: 1.0466e-04 - loss/regularization_BendingEnergy_weighted: 5.2329e-05 - loss/image_GlobalMutualInformationLoss: -0.0685 - loss/image_GlobalMutualInformationLoss_weighted: -0.0342 - loss/label_L2_Distance: 7.1201 - loss/label_L2_Distance_weighted: 0.0712 - val_loss: 0.0360 - val_loss/regularization_BendingEnergy: 7.6675e-05 - val_loss/regularization_BendingEnergy_weighted: 3.8337e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0604 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0302 - val_loss/label_L2_Distance: 6.6123 - val_loss/label_L2_Distance_weighted: 0.0661
# Epoch 59/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0914 - loss/regularization_BendingEnergy: 1.0701e-04 - loss/regularization_BendingEnergy_weighted: 5.3506e-05 - loss/image_GlobalMutualInformationLoss: -0.0649 - loss/image_GlobalMutualInformationLoss_weighted: -0.0325 - loss/label_L2_Distance: 12.3779 - loss/label_L2_Distance_weighted: 0.1238 - val_loss: 0.0740 - val_loss/regularization_BendingEnergy: 1.3315e-04 - val_loss/regularization_BendingEnergy_weighted: 6.6574e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0594 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0297 - val_loss/label_L2_Distance: 10.3644 - val_loss/label_L2_Distance_weighted: 0.1036
# Epoch 60/4000
# 8/8 [==============================] - 34s 4s/step - loss: 0.1293 - loss/regularization_BendingEnergy: 1.0390e-04 - loss/regularization_BendingEnergy_weighted: 5.1950e-05 - loss/image_GlobalMutualInformationLoss: -0.0438 - loss/image_GlobalMutualInformationLoss_weighted: -0.0219 - loss/label_L2_Distance: 15.1135 - loss/label_L2_Distance_weighted: 0.1511 - val_loss: 0.0951 - val_loss/regularization_BendingEnergy: 1.7151e-04 - val_loss/regularization_BendingEnergy_weighted: 8.5753e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 12.4577 - val_loss/label_L2_Distance_weighted: 0.1246
# Epoch 61/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0677 - loss/regularization_BendingEnergy: 1.0529e-04 - loss/regularization_BendingEnergy_weighted: 5.2644e-05 - loss/image_GlobalMutualInformationLoss: -0.0431 - loss/image_GlobalMutualInformationLoss_weighted: -0.0215 - loss/label_L2_Distance: 8.9138 - loss/label_L2_Distance_weighted: 0.0891 - val_loss: 0.0701 - val_loss/regularization_BendingEnergy: 1.3851e-04 - val_loss/regularization_BendingEnergy_weighted: 6.9256e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0589 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 9.9537 - val_loss/label_L2_Distance_weighted: 0.0995
# Epoch 62/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0685 - loss/regularization_BendingEnergy: 1.0023e-04 - loss/regularization_BendingEnergy_weighted: 5.0116e-05 - loss/image_GlobalMutualInformationLoss: -0.0459 - loss/image_GlobalMutualInformationLoss_weighted: -0.0229 - loss/label_L2_Distance: 9.1365 - loss/label_L2_Distance_weighted: 0.0914 - val_loss: 0.0500 - val_loss/regularization_BendingEnergy: 1.0811e-04 - val_loss/regularization_BendingEnergy_weighted: 5.4055e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0590 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 7.9435 - val_loss/label_L2_Distance_weighted: 0.0794
# Epoch 63/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0250 - loss/regularization_BendingEnergy: 1.0365e-04 - loss/regularization_BendingEnergy_weighted: 5.1823e-05 - loss/image_GlobalMutualInformationLoss: -0.0604 - loss/image_GlobalMutualInformationLoss_weighted: -0.0302 - loss/label_L2_Distance: 5.5095 - loss/label_L2_Distance_weighted: 0.0551 - val_loss: 0.0447 - val_loss/regularization_BendingEnergy: 1.0934e-04 - val_loss/regularization_BendingEnergy_weighted: 5.4669e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0594 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0297 - val_loss/label_L2_Distance: 7.4385 - val_loss/label_L2_Distance_weighted: 0.0744
# Epoch 64/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1353 - loss/regularization_BendingEnergy: 1.1341e-04 - loss/regularization_BendingEnergy_weighted: 5.6706e-05 - loss/image_GlobalMutualInformationLoss: -0.0604 - loss/image_GlobalMutualInformationLoss_weighted: -0.0302 - loss/label_L2_Distance: 16.5422 - loss/label_L2_Distance_weighted: 0.1654 - val_loss: 0.0344 - val_loss/regularization_BendingEnergy: 9.8165e-05 - val_loss/regularization_BendingEnergy_weighted: 4.9082e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0602 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0301 - val_loss/label_L2_Distance: 6.4487 - val_loss/label_L2_Distance_weighted: 0.0645
# Epoch 65/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0559 - loss/regularization_BendingEnergy: 1.2893e-04 - loss/regularization_BendingEnergy_weighted: 6.4463e-05 - loss/image_GlobalMutualInformationLoss: -0.0543 - loss/image_GlobalMutualInformationLoss_weighted: -0.0272 - loss/label_L2_Distance: 8.2947 - loss/label_L2_Distance_weighted: 0.0829 - val_loss: 0.0241 - val_loss/regularization_BendingEnergy: 8.2946e-05 - val_loss/regularization_BendingEnergy_weighted: 4.1473e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0605 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0302 - val_loss/label_L2_Distance: 5.4327 - val_loss/label_L2_Distance_weighted: 0.0543
# Epoch 66/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0444 - loss/regularization_BendingEnergy: 1.3394e-04 - loss/regularization_BendingEnergy_weighted: 6.6969e-05 - loss/image_GlobalMutualInformationLoss: -0.0554 - loss/image_GlobalMutualInformationLoss_weighted: -0.0277 - loss/label_L2_Distance: 7.2045 - loss/label_L2_Distance_weighted: 0.0720 - val_loss: 0.0071 - val_loss/regularization_BendingEnergy: 6.7769e-05 - val_loss/regularization_BendingEnergy_weighted: 3.3885e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0602 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0301 - val_loss/label_L2_Distance: 3.7186 - val_loss/label_L2_Distance_weighted: 0.0372
# Epoch 67/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0719 - loss/regularization_BendingEnergy: 1.3777e-04 - loss/regularization_BendingEnergy_weighted: 6.8887e-05 - loss/image_GlobalMutualInformationLoss: -0.0608 - loss/image_GlobalMutualInformationLoss_weighted: -0.0304 - loss/label_L2_Distance: 10.2226 - loss/label_L2_Distance_weighted: 0.1022 - val_loss: 4.9654e-04 - val_loss/regularization_BendingEnergy: 5.4820e-05 - val_loss/regularization_BendingEnergy_weighted: 2.7410e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0599 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0300 - val_loss/label_L2_Distance: 3.0429 - val_loss/label_L2_Distance_weighted: 0.0304
# Epoch 68/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1533 - loss/regularization_BendingEnergy: 1.3962e-04 - loss/regularization_BendingEnergy_weighted: 6.9809e-05 - loss/image_GlobalMutualInformationLoss: -0.0678 - loss/image_GlobalMutualInformationLoss_weighted: -0.0339 - loss/label_L2_Distance: 18.7148 - loss/label_L2_Distance_weighted: 0.1871 - val_loss: -0.0041 - val_loss/regularization_BendingEnergy: 4.1308e-05 - val_loss/regularization_BendingEnergy_weighted: 2.0654e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0598 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0299 - val_loss/label_L2_Distance: 2.5769 - val_loss/label_L2_Distance_weighted: 0.0258
# Epoch 69/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1877 - loss/regularization_BendingEnergy: 1.3199e-04 - loss/regularization_BendingEnergy_weighted: 6.5997e-05 - loss/image_GlobalMutualInformationLoss: -0.0457 - loss/image_GlobalMutualInformationLoss_weighted: -0.0228 - loss/label_L2_Distance: 21.0448 - loss/label_L2_Distance_weighted: 0.2104 - val_loss: -0.0027 - val_loss/regularization_BendingEnergy: 5.9189e-05 - val_loss/regularization_BendingEnergy_weighted: 2.9594e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0597 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0299 - val_loss/label_L2_Distance: 2.7117 - val_loss/label_L2_Distance_weighted: 0.0271
# Epoch 70/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.1052 - loss/regularization_BendingEnergy: 1.2584e-04 - loss/regularization_BendingEnergy_weighted: 6.2919e-05 - loss/image_GlobalMutualInformationLoss: -0.0379 - loss/image_GlobalMutualInformationLoss_weighted: -0.0190 - loss/label_L2_Distance: 12.4078 - loss/label_L2_Distance_weighted: 0.1241 - val_loss: 0.0028 - val_loss/regularization_BendingEnergy: 8.7452e-05 - val_loss/regularization_BendingEnergy_weighted: 4.3726e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0597 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0298 - val_loss/label_L2_Distance: 3.2638 - val_loss/label_L2_Distance_weighted: 0.0326
# Epoch 71/4000
# 8/8 [==============================] - 33s 4s/step - loss: 0.0413 - loss/regularization_BendingEnergy: 1.3389e-04 - loss/regularization_BendingEnergy_weighted: 6.6947e-05 - loss/image_GlobalMutualInformationLoss: -0.0393 - loss/image_GlobalMutualInformationLoss_weighted: -0.0197 - loss/label_L2_Distance: 6.0920 - loss/label_L2_Distance_weighted: 0.0609 - val_loss: 0.0129 - val_loss/regularization_BendingEnergy: 1.1777e-04 - val_loss/regularization_BendingEnergy_weighted: 5.8884e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0596 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0298 - val_loss/label_L2_Distance: 4.2608 - val_loss/label_L2_Distance_weighted: 0.0426
# Epoch 72/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0195 - loss/regularization_BendingEnergy: 1.2375e-04 - loss/regularization_BendingEnergy_weighted: 6.1874e-05 - loss/image_GlobalMutualInformationLoss: -0.0774 - loss/image_GlobalMutualInformationLoss_weighted: -0.0387 - loss/label_L2_Distance: 5.8163 - loss/label_L2_Distance_weighted: 0.0582 - val_loss: 0.0448 - val_loss/regularization_BendingEnergy: 1.9002e-04 - val_loss/regularization_BendingEnergy_weighted: 9.5012e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0590 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - val_loss/label_L2_Distance: 7.4233 - val_loss/label_L2_Distance_weighted: 0.0742
# Epoch 73/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0407 - loss/regularization_BendingEnergy: 1.1774e-04 - loss/regularization_BendingEnergy_weighted: 5.8869e-05 - loss/image_GlobalMutualInformationLoss: -0.0528 - loss/image_GlobalMutualInformationLoss_weighted: -0.0264 - loss/label_L2_Distance: 6.7048 - loss/label_L2_Distance_weighted: 0.0670 - val_loss: 0.0969 - val_loss/regularization_BendingEnergy: 2.5089e-04 - val_loss/regularization_BendingEnergy_weighted: 1.2544e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0585 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0293 - val_loss/label_L2_Distance: 12.6040 - val_loss/label_L2_Distance_weighted: 0.1260
# Epoch 74/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0469 - loss/regularization_BendingEnergy: 1.1780e-04 - loss/regularization_BendingEnergy_weighted: 5.8900e-05 - loss/image_GlobalMutualInformationLoss: -0.0387 - loss/image_GlobalMutualInformationLoss_weighted: -0.0194 - loss/label_L2_Distance: 6.6223 - loss/label_L2_Distance_weighted: 0.0662 - val_loss: 0.1256 - val_loss/regularization_BendingEnergy: 2.5942e-04 - val_loss/regularization_BendingEnergy_weighted: 1.2971e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0591 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0296 - val_loss/label_L2_Distance: 15.5078 - val_loss/label_L2_Distance_weighted: 0.1551
# Epoch 75/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.2048 - loss/regularization_BendingEnergy: 1.4483e-04 - loss/regularization_BendingEnergy_weighted: 7.2417e-05 - loss/image_GlobalMutualInformationLoss: -0.0591 - loss/image_GlobalMutualInformationLoss_weighted: -0.0295 - loss/label_L2_Distance: 23.4229 - loss/label_L2_Distance_weighted: 0.2342 - val_loss: 0.1274 - val_loss/regularization_BendingEnergy: 2.3674e-04 - val_loss/regularization_BendingEnergy_weighted: 1.1837e-04 - val_loss/image_GlobalMutualInformationLoss: -0.0601 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0301 - val_loss/label_L2_Distance: 15.7323 - val_loss/label_L2_Distance_weighted: 0.1573
# Epoch 76/4000
# 8/8 [==============================] - 32s 4s/step - loss: 0.0554 - loss/regularization_BendingEnergy: 1.2778e-04 - loss/regularization_BendingEnergy_weighted: 6.3890e-05 - loss/image_GlobalMutualInformationLoss: -0.0470 - loss/image_GlobalMutualInformationLoss_weighted: -0.0235 - loss/label_L2_Distance: 7.8868 - loss/label_L2_Distance_weighted: 0.0789 - val_loss: 0.1061 - val_loss/regularization_BendingEnergy: 1.8060e-04 - val_loss/regularization_BendingEnergy_weighted: 9.0302e-05 - val_loss/image_GlobalMutualInformationLoss: -0.0603 - val_loss/image_GlobalMutualInformationLoss_weighted: -0.0301 - val_loss/label_L2_Distance: 13.6175 - val_loss/label_L2_Distance_weighted: 0.1362
# Epoch 77/4000
# 2/8 [======>.......................] - ETA: 10s - loss: 0.0183 - loss/regularization_BendingEnergy: 1.2037e-04 - loss/regularization_BendingEnergy_weighted: 6.0186e-05 - loss/image_GlobalMutualInformationLoss: -0.1031 - loss/image_GlobalMutualInformationLoss_weighted: -0.0516 - loss/label_L2_Distance: 6.9795 - loss/label_L2_Distance_weighted: 0.0698
