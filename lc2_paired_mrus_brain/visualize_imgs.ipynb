# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib

# %%
d='/home/dinankg/EECS556/eecs556_MMIR/lc2_paired_mrus_brain/logs_reg'
f='fixed_image.nii.gz'
m='moving_image.nii.gz'
nii = nib.load(f'{d}/{f}')
fixed = nii.get_fdata()
nii = nib.load(f'{d}/{m}')
moving = nii.get_fdata()

# %%
sl=40
fig = plt.figure(frameon=False)

im1 = plt.imshow(moving[:,:,40], cmap=plt.cm.gray,vmin=0.2,vmax=0.6)

im2 = plt.imshow(fixed[:,:,sl], cmap=plt.cm.hot_r, alpha=.5)

plt.show()
